# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
EXPORT_DIR = "data/facteurs_systemiq"
Z_hat = pd.read_csv(f"{EXPORT_DIR}/Z_finance.csv")

# %%
Z_hat.rename(columns={"Unnamed: 0": "quarter"}, inplace=True)

# %%
# Charger le fichier Excel
df_macro_raw= pd.read_excel("data\macro_data\Données_macro_hist_v2.xlsx")

# Afficher les premières lignes
df_macro_raw
# Out:
#             Region                                           Variable  \
# 0        Argentina  Central bank Intervention rate (policy interes...
# 1        Argentina                            Effective exchange rate
# 2        Argentina                                      Exchange_rate
# 3        Argentina                                    GDP Growth Rate
# 4        Australia  Central bank Intervention rate (policy interes...
# ..             ...                                                ...
# 246  United States                                     Inflation rate
# 247  United States                            Long term interest rate
# 248  United States                                          Oil price
# 249  United States                                  Unemployment rate
# 250          World                                          Oil price
#
#                        Unit     2010-Q1     2010-Q2     2010-Q3     2010-Q4  \
# 0                         %    9.500000    9.500000    9.500000    9.500000
# 1           index; 2017=100  180.006667  182.946667  181.750000  177.056667
# 2    local currency per US$    3.830000    3.880000    3.920000    3.950000
# 3                         %    3.131891    4.307855    0.557817    1.184901
# 4                         %    3.833333    4.416667    4.500000    4.666667
# ..                      ...         ...         ...         ...         ...
# 246                       %    2.360525    1.767765    1.175609    1.270248
# 247                       %    3.716667    3.490000    2.786667    2.863333
# 248          US$ per barrel   76.674837   78.845036   76.675000   87.033160
# 249                       %    9.833333    9.633333    9.466666    9.500000
# 250          US$ per barrel   76.674837   78.845036   76.675000   87.033160
#
#         2011-Q1     2011-Q2     2011-Q3  ...    2022-Q4    2023-Q1    2023-Q2  \
# 0      9.500000    9.500000    9.500000  ...        NaN        NaN        NaN
# 1    174.323333  167.796667  169.263333  ...        NaN        NaN        NaN
# 2      3.990000    4.060000    4.150000  ...        NaN        NaN        NaN
# 3      2.388622    1.192061    0.842933  ...        NaN        NaN        NaN
# 4      4.750000    4.750000    4.750000  ...        NaN        NaN        NaN
# ..          ...         ...         ...  ...        ...        ...        ...
# 246    2.141127    3.430395    3.756174  ...   7.103384   5.810245   3.982369
# 247    3.460000    3.210000    2.426667  ...   3.830000   3.646667   3.593333
# 248  105.369424  117.541905  113.266948  ...  88.720130  82.323613  78.086130
# 249    9.033334    9.066667    9.000000  ...   3.566667   3.533333   3.533333
# 250  105.369424  117.541905  113.266948  ...  88.720130  82.323613  78.086130
#
#        2023-Q3    2023-Q4    2024-Q1    2024-Q2    2024-Q3    2024-Q4  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 246   3.514197   3.243513   3.240480   3.199263   2.622039   2.745114
# 247   4.150000   4.440000   4.160000   4.443333   3.946667   4.283333
# 248  85.983547  82.891681  81.955714  84.981986  78.708317  74.000940
# 249   3.666667   3.800000   3.833333   4.000000   4.166667   4.133333
# 250  85.983547  82.891681  81.955714  84.981986  78.708317  74.000940
#
#        2025-Q1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 246   2.737586
# 247   4.453333
# 248  75.042781
# 249   4.100000
# 250  75.042781
#
# [251 rows x 64 columns]

# %%
df = df_macro_raw.copy()

id_cols = ["Region", "Variable", "Unit"]
value_cols = [c for c in df.columns if c not in id_cols]

df_long = df.melt(
    id_vars=id_cols,
    value_vars=value_cols,
    var_name="quarter",
    value_name="value"
)

df_long.head()
# Out:
#       Region                                           Variable  \
# 0  Argentina  Central bank Intervention rate (policy interes...
# 1  Argentina                            Effective exchange rate
# 2  Argentina                                      Exchange_rate
# 3  Argentina                                    GDP Growth Rate
# 4  Australia  Central bank Intervention rate (policy interes...
#
#                      Unit  quarter       value
# 0                       %  2010-Q1    9.500000
# 1         index; 2017=100  2010-Q1  180.006667
# 2  local currency per US$  2010-Q1    3.830000
# 3                       %  2010-Q1    3.131891
# 4                       %  2010-Q1    3.833333

# %%
Z_hat
# Out:
#        quarter        Zt
# 0   2010-07-01 -0.113729
# 1   2010-10-01  0.865167
# 2   2011-01-01  1.182152
# 3   2011-04-01  1.001547
# 4   2011-07-01  0.093760
# 5   2011-10-01 -0.582303
# 6   2012-01-01 -0.634776
# 7   2012-04-01  0.219300
# 8   2012-07-01  0.027697
# 9   2012-10-01  0.401578
# 10  2013-01-01 -0.069836
# 11  2013-04-01 -0.096481
# 12  2013-07-01  0.924171
# 13  2013-10-01  0.727494
# 14  2014-01-01  0.802684
# 15  2014-04-01  0.424726
# 16  2014-07-01 -0.005408
# 17  2014-10-01 -0.198245
# 18  2015-01-01 -0.172365
# 19  2015-04-01 -0.519077
# 20  2015-07-01 -0.445036
# 21  2015-10-01 -0.009234
# 22  2016-01-01  0.034046
# 23  2016-04-01  0.239146
# 24  2016-07-01 -0.222951
# 25  2016-10-01 -0.752658
# 26  2017-01-01 -0.620566
# 27  2017-04-01 -0.348269
# 28  2017-07-01 -0.162695
# 29  2017-10-01  0.110625
# 30  2018-01-01  0.341075
# 31  2018-04-01  0.280355
# 32  2018-07-01  0.359940
# 33  2018-10-01 -0.471350
# 34  2019-01-01 -0.962522
# 35  2019-04-01 -1.927952
# 36  2019-07-01 -1.788685
# 37  2019-10-01 -1.663545
# 38  2020-01-01 -1.105886
# 39  2020-04-01  0.092922
# 40  2020-07-01  0.734780
# 41  2020-10-01  1.435027
# 42  2021-01-01  1.531983
# 43  2021-04-01  1.339270
# 44  2021-07-01  0.823792
# 45  2021-10-01 -0.032476
# 46  2022-01-01 -0.030913
# 47  2022-04-01  0.223604
# 48  2022-07-01 -0.395155
# 49  2022-10-01 -0.750896
# 50  2023-01-01 -0.364328
# 51  2023-04-01 -1.696752

# %% [markdown]
# Nous allons récupérer les variables macroéconomiques à considérer pour la modélisation des facteurs systémiques. D'abord, au regard des données dont nous disposons, nous ne pouvons considérer que les variables provenant des régions d'EUrope (5 variables disponibles) et des US (9 variables disponibles).

# %%
# Sélection des régions
regions_keep = ["United States"]
df = df_macro_raw[df_macro_raw["Region"].isin(regions_keep)].copy()

# %%
# Colonnes temporelles
time_cols = [c for c in df.columns if "-" in c]
# On garde uniquement les lignes sans NaN sur toute la période
df = df.dropna(subset=time_cols)

# %%
# Mapping régions → suffixes
region_map = {
    "United States": "US"
}

def clean_var_name(var):
    return (
        var.strip()
           .replace(" ", "_")
           .replace("(", "")
           .replace(")", "")
           .replace("/", "_")
    )

df["var_name"] = (
    df["Region"].map(region_map)
    + "_"
    + df["Variable"].apply(clean_var_name)
)

# %%
# Passage au format long
df_long = df.melt(
    id_vars=["var_name"],
    value_vars=time_cols,
    var_name="date",
    value_name="value"
)

# Pivot final
df_ts = df_long.pivot(
    index="date",
    columns="var_name",
    values="value"
).sort_index()

# %%
# Conversion "2010-Q1" → PeriodIndex trimestriel
df_ts.index = pd.PeriodIndex(df_ts.index, freq="Q").to_timestamp()

# %%
df_ts['quarter']=df_ts.index

# %%
df_ts
# Out:
# var_name    US_Central_bank_Intervention_rate_policy_interest_rate  \
# date
# 2010-01-01                                           0.125000
# 2010-04-01                                           0.125000
# 2010-07-01                                           0.125000
# 2010-10-01                                           0.125000
# 2011-01-01                                           0.125000
# ...                                                       ...
# 2024-01-01                                           5.375000
# 2024-04-01                                           5.375000
# 2024-07-01                                           5.208333
# 2024-10-01                                           4.625000
# 2025-01-01                                           4.375000
#
# var_name    US_Effective_exchange_rate  US_Equity_prices  US_GDP_Growth_Rate  \
# date
# 2010-01-01                   84.740000         46.875171            0.484501
# 2010-04-01                   86.106667         41.314746            0.967586
# 2010-07-01                   84.923333         45.743602            0.771085
# 2010-10-01                   81.390000         50.410959            0.525110
# 2011-01-01                   80.343333         53.144269           -0.237205
# ...                                ...               ...                 ...
# 2024-01-01                  107.953333        210.614185            0.404802
# 2024-04-01                  110.086667        218.876649            0.738980
# 2024-07-01                  109.493333        230.981949            0.759510
# 2024-10-01                  111.980000        235.757927            0.607065
# 2025-01-01                  114.066667        223.705139           -0.060750
#
# var_name    US_House_prices_residential  US_Inflation_rate  \
# date
# 2010-01-01                    94.481014           2.360525
# 2010-04-01                    93.876843           1.767765
# 2010-07-01                    92.137491           1.175609
# 2010-10-01                    90.641295           1.270248
# 2011-01-01                    87.908116           2.141127
# ...                                 ...                ...
# 2024-01-01                   153.875453           3.240480
# 2024-04-01                   154.462696           3.199263
# 2024-07-01                   155.181924           2.622039
# 2024-10-01                   156.414644           2.745114
# 2025-01-01                   156.150481           2.737586
#
# var_name    US_Long_term_interest_rate  US_Oil_price  US_Unemployment_rate  \
# date
# 2010-01-01                    3.716667     76.674837              9.833333
# 2010-04-01                    3.490000     78.845036              9.633333
# 2010-07-01                    2.786667     76.675000              9.466666
# 2010-10-01                    2.863333     87.033160              9.500000
# 2011-01-01                    3.460000    105.369424              9.033334
# ...                                ...           ...                   ...
# 2024-01-01                    4.160000     81.955714              3.833333
# 2024-04-01                    4.443333     84.981986              4.000000
# 2024-07-01                    3.946667     78.708317              4.166667
# 2024-10-01                    4.283333     74.000940              4.133333
# 2025-01-01                    4.453333     75.042781              4.100000
#
# var_name      quarter
# date
# 2010-01-01 2010-01-01
# 2010-04-01 2010-04-01
# 2010-07-01 2010-07-01
# 2010-10-01 2010-10-01
# 2011-01-01 2011-01-01
# ...               ...
# 2024-01-01 2024-01-01
# 2024-04-01 2024-04-01
# 2024-07-01 2024-07-01
# 2024-10-01 2024-10-01
# 2025-01-01 2025-01-01
#
# [61 rows x 10 columns]

# %%
Z_hat
# Out:
#        quarter        Zt
# 0   2010-07-01 -0.113729
# 1   2010-10-01  0.865167
# 2   2011-01-01  1.182152
# 3   2011-04-01  1.001547
# 4   2011-07-01  0.093760
# 5   2011-10-01 -0.582303
# 6   2012-01-01 -0.634776
# 7   2012-04-01  0.219300
# 8   2012-07-01  0.027697
# 9   2012-10-01  0.401578
# 10  2013-01-01 -0.069836
# 11  2013-04-01 -0.096481
# 12  2013-07-01  0.924171
# 13  2013-10-01  0.727494
# 14  2014-01-01  0.802684
# 15  2014-04-01  0.424726
# 16  2014-07-01 -0.005408
# 17  2014-10-01 -0.198245
# 18  2015-01-01 -0.172365
# 19  2015-04-01 -0.519077
# 20  2015-07-01 -0.445036
# 21  2015-10-01 -0.009234
# 22  2016-01-01  0.034046
# 23  2016-04-01  0.239146
# 24  2016-07-01 -0.222951
# 25  2016-10-01 -0.752658
# 26  2017-01-01 -0.620566
# 27  2017-04-01 -0.348269
# 28  2017-07-01 -0.162695
# 29  2017-10-01  0.110625
# 30  2018-01-01  0.341075
# 31  2018-04-01  0.280355
# 32  2018-07-01  0.359940
# 33  2018-10-01 -0.471350
# 34  2019-01-01 -0.962522
# 35  2019-04-01 -1.927952
# 36  2019-07-01 -1.788685
# 37  2019-10-01 -1.663545
# 38  2020-01-01 -1.105886
# 39  2020-04-01  0.092922
# 40  2020-07-01  0.734780
# 41  2020-10-01  1.435027
# 42  2021-01-01  1.531983
# 43  2021-04-01  1.339270
# 44  2021-07-01  0.823792
# 45  2021-10-01 -0.032476
# 46  2022-01-01 -0.030913
# 47  2022-04-01  0.223604
# 48  2022-07-01 -0.395155
# 49  2022-10-01 -0.750896
# 50  2023-01-01 -0.364328
# 51  2023-04-01 -1.696752

# %%
df_ts.rename(columns={"date": "quarter"}, inplace=True)

# %%
df_ts.columns
# Out:
# Index(['US_Central_bank_Intervention_rate_policy_interest_rate',
#        'US_Effective_exchange_rate', 'US_Equity_prices', 'US_GDP_Growth_Rate',
#        'US_House_prices_residential', 'US_Inflation_rate',
#        'US_Long_term_interest_rate', 'US_Oil_price', 'US_Unemployment_rate',
#        'quarter'],
#       dtype='object', name='var_name')

# %%
Z_hat
# Out:
#        quarter        Zt
# 0   2010-07-01 -0.113729
# 1   2010-10-01  0.865167
# 2   2011-01-01  1.182152
# 3   2011-04-01  1.001547
# 4   2011-07-01  0.093760
# 5   2011-10-01 -0.582303
# 6   2012-01-01 -0.634776
# 7   2012-04-01  0.219300
# 8   2012-07-01  0.027697
# 9   2012-10-01  0.401578
# 10  2013-01-01 -0.069836
# 11  2013-04-01 -0.096481
# 12  2013-07-01  0.924171
# 13  2013-10-01  0.727494
# 14  2014-01-01  0.802684
# 15  2014-04-01  0.424726
# 16  2014-07-01 -0.005408
# 17  2014-10-01 -0.198245
# 18  2015-01-01 -0.172365
# 19  2015-04-01 -0.519077
# 20  2015-07-01 -0.445036
# 21  2015-10-01 -0.009234
# 22  2016-01-01  0.034046
# 23  2016-04-01  0.239146
# 24  2016-07-01 -0.222951
# 25  2016-10-01 -0.752658
# 26  2017-01-01 -0.620566
# 27  2017-04-01 -0.348269
# 28  2017-07-01 -0.162695
# 29  2017-10-01  0.110625
# 30  2018-01-01  0.341075
# 31  2018-04-01  0.280355
# 32  2018-07-01  0.359940
# 33  2018-10-01 -0.471350
# 34  2019-01-01 -0.962522
# 35  2019-04-01 -1.927952
# 36  2019-07-01 -1.788685
# 37  2019-10-01 -1.663545
# 38  2020-01-01 -1.105886
# 39  2020-04-01  0.092922
# 40  2020-07-01  0.734780
# 41  2020-10-01  1.435027
# 42  2021-01-01  1.531983
# 43  2021-04-01  1.339270
# 44  2021-07-01  0.823792
# 45  2021-10-01 -0.032476
# 46  2022-01-01 -0.030913
# 47  2022-04-01  0.223604
# 48  2022-07-01 -0.395155
# 49  2022-10-01 -0.750896
# 50  2023-01-01 -0.364328
# 51  2023-04-01 -1.696752

# %%
df_full = pd.concat([df_ts, Z_hat], axis=1, join="inner"

# %%
df_full
# Out:
# Empty DataFrame
# Columns: [US_Central_bank_Intervention_rate_policy_interest_rate, US_Effective_exchange_rate, US_Equity_prices, US_GDP_Growth_Rate, US_House_prices_residential, US_Inflation_rate, US_Long_term_interest_rate, US_Oil_price, US_Unemployment_rate, quarter, quarter, Zt]
# Index: []

# %%
df_full['quarter'] =df_full['quarter'].astype(str)

# %%
df_full
# Out:
#        quarter  US_Central_bank_Intervention_rate_policy_interest_rate  \
# 0   2010-01-01                                           0.125000
# 1   2010-04-01                                           0.125000
# 2   2010-07-01                                           0.125000
# 3   2010-10-01                                           0.125000
# 4   2011-01-01                                           0.125000
# 5   2011-04-01                                           0.125000
# 6   2011-07-01                                           0.125000
# 7   2011-10-01                                           0.125000
# 8   2012-01-01                                           0.125000
# 9   2012-04-01                                           0.125000
# 10  2012-07-01                                           0.125000
# 11  2012-10-01                                           0.125000
# 12  2013-01-01                                           0.125000
# 13  2013-04-01                                           0.125000
# 14  2013-07-01                                           0.125000
# 15  2013-10-01                                           0.125000
# 16  2014-01-01                                           0.125000
# 17  2014-04-01                                           0.125000
# 18  2014-07-01                                           0.125000
# 19  2014-10-01                                           0.125000
# 20  2015-01-01                                           0.125000
# 21  2015-04-01                                           0.125000
# 22  2015-07-01                                           0.125000
# 23  2015-10-01                                           0.208333
# 24  2016-01-01                                           0.375000
# 25  2016-04-01                                           0.375000
# 26  2016-07-01                                           0.375000
# 27  2016-10-01                                           0.458333
# 28  2017-01-01                                           0.708333
# 29  2017-04-01                                           0.958333
# 30  2017-07-01                                           1.125000
# 31  2017-10-01                                           1.208333
# 32  2018-01-01                                           1.458333
# 33  2018-04-01                                           1.708333
# 34  2018-07-01                                           1.958333
# 35  2018-10-01                                           2.208333
# 36  2019-01-01                                           2.375000
# 37  2019-04-01                                           2.375000
# 38  2019-07-01                                           2.125000
# 39  2019-10-01                                           1.625000
# 40  2020-01-01                                           1.125000
# 41  2020-04-01                                           0.125000
# 48                    1.940000     97.443127              3.833333
# 49                    2.930000    111.987359              3.633333
# 50                    3.106667     97.834694              3.533333
# 51                    3.830000     88.720130              3.566667
#
#        quarter        Zt
# 0   2010-07-01 -0.113729
# 1   2010-10-01  0.865167
# 2   2011-01-01  1.182152
# 3   2011-04-01  1.001547
# 4   2011-07-01  0.093760
# 5   2011-10-01 -0.582303
# 6   2012-01-01 -0.634776
# 7   2012-04-01  0.219300
# 8   2012-07-01  0.027697
# 9   2012-10-01  0.401578
# 10  2013-01-01 -0.069836
# 11  2013-04-01 -0.096481
# 12  2013-07-01  0.924171
# 13  2013-10-01  0.727494
# 14  2014-01-01  0.802684
# 15  2014-04-01  0.424726
# 16  2014-07-01 -0.005408
# 17  2014-10-01 -0.198245
# 18  2015-01-01 -0.172365
# 19  2015-04-01 -0.519077
# 20  2015-07-01 -0.445036
# 21  2015-10-01 -0.009234
# 22  2016-01-01  0.034046
# 23  2016-04-01  0.239146
# 24  2016-07-01 -0.222951
# 25  2016-10-01 -0.752658
# 26  2017-01-01 -0.620566
# 27  2017-04-01 -0.348269
# 28  2017-07-01 -0.162695
# 29  2017-10-01  0.110625
# 30  2018-01-01  0.341075
# 31  2018-04-01  0.280355
# 32  2018-07-01  0.359940
# 33  2018-10-01 -0.471350
# 34  2019-01-01 -0.962522
# 35  2019-04-01 -1.927952
# 36  2019-07-01 -1.788685
# 37  2019-10-01 -1.663545
# 38  2020-01-01 -1.105886
# 39  2020-04-01  0.092922
# 40  2020-07-01  0.734780
# 41  2020-10-01  1.435027
# 42  2021-01-01  1.531983
# 43  2021-04-01  1.339270
# 44  2021-07-01  0.823792
# 45  2021-10-01 -0.032476
# 46  2022-01-01 -0.030913
# 47  2022-04-01  0.223604
# 48  2022-07-01 -0.395155
# 49  2022-10-01 -0.750896
# 50  2023-01-01 -0.364328
# 51  2023-04-01 -1.696752

# %%
df_full = df_full.set_index("quarter")

# %%
df_full
# Out:
#                           US_Central_bank_Intervention_rate_policy_interest_rate  \
# quarter
# (2010-01-01, 2010-07-01)                                           0.125000
# (2010-04-01, 2010-10-01)                                           0.125000
# (2010-07-01, 2011-01-01)                                           0.125000
# (2010-10-01, 2011-04-01)                                           0.125000
# (2011-01-01, 2011-07-01)                                           0.125000
# (2011-04-01, 2011-10-01)                                           0.125000
# (2011-07-01, 2012-01-01)                                           0.125000
# (2011-10-01, 2012-04-01)                                           0.125000
# (2012-01-01, 2012-07-01)                                           0.125000
# (2012-04-01, 2012-10-01)                                           0.125000
# (2012-07-01, 2013-01-01)                                           0.125000
# (2012-10-01, 2013-04-01)                                           0.125000
# (2013-01-01, 2013-07-01)                                           0.125000
# (2013-04-01, 2013-10-01)                                           0.125000
# (2013-07-01, 2014-01-01)                                           0.125000
# (2013-10-01, 2014-04-01)                                           0.125000
# (2014-01-01, 2014-07-01)                                           0.125000
# (2014-04-01, 2014-10-01)                                           0.125000
# (2014-07-01, 2015-01-01)                                           0.125000
# (2014-10-01, 2015-04-01)                                           0.125000
# (2015-01-01, 2015-07-01)                                           0.125000
# (2015-01-01, 2015-07-01)     54.570576              5.533333 -0.445036
# (2015-04-01, 2015-10-01)     62.546724              5.433333 -0.009234
# (2015-07-01, 2016-01-01)     50.797943              5.100000  0.034046
# (2015-10-01, 2016-04-01)     44.175606              5.033333  0.239146
# (2016-01-01, 2016-07-01)     35.199931              4.900000 -0.222951
# (2016-04-01, 2016-10-01)     46.980916              4.933333 -0.752658
# (2016-07-01, 2017-01-01)     47.009188              4.900000 -0.620566
# (2016-10-01, 2017-04-01)     51.126270              4.766667 -0.348269
# (2017-01-01, 2017-07-01)     54.820709              4.566667 -0.162695
# (2017-04-01, 2017-10-01)     51.001692              4.366667  0.110625
# (2017-07-01, 2018-01-01)     52.246259              4.333333  0.341075
# (2017-10-01, 2018-04-01)     61.479004              4.166667  0.280355
# (2018-01-01, 2018-07-01)     67.159150              4.033333  0.359940
# (2018-04-01, 2018-10-01)     74.890021              3.933333 -0.471350
# (2018-07-01, 2019-01-01)     76.081132              3.766667 -0.962522
# (2018-10-01, 2019-04-01)     68.320070              3.833333 -1.927952
# (2019-01-01, 2019-07-01)     63.756896              3.866667 -1.788685
# (2019-04-01, 2019-10-01)     68.357847              3.633333 -1.663545
# (2019-07-01, 2020-01-01)     62.123769              3.600000 -1.105886
# (2019-10-01, 2020-04-01)     62.555384              3.600000  0.092922
# (2020-01-01, 2020-07-01)     51.178989              3.833333  0.734780
# (2020-04-01, 2020-10-01)     33.377157             13.000000  1.435027
# (2020-07-01, 2021-01-01)     43.434633              8.800000  1.531983
# (2020-10-01, 2021-04-01)     45.344592              6.733333  1.339270
# (2021-01-01, 2021-07-01)     61.127783              6.233333  0.823792
# (2021-04-01, 2021-10-01)     69.139928              5.933333 -0.032476
# (2021-07-01, 2022-01-01)     73.246970              5.066667 -0.030913
# (2021-10-01, 2022-04-01)     79.811318              4.166667  0.223604
# (2022-01-01, 2022-07-01)     97.443127              3.833333 -0.395155
# (2022-04-01, 2022-10-01)    111.987359              3.633333 -0.750896
# (2022-07-01, 2023-01-01)     97.834694              3.533333 -0.364328
# (2022-10-01, 2023-04-01)     88.720130              3.566667 -1.696752

# %%
# check NaN sur les Z
na_rate = df_full.filter(like="Z_").isna().mean().sort_values()
print(na_rate.head(10))
print("\nPires colonnes Z (beaucoup de NaN):")
print(na_rate.tail(10))
# Out:
# Series([], dtype: float64)
#
# Pires colonnes Z (beaucoup de NaN):
# Series([], dtype: float64)

# %%
df_full
# Out:
#                                    US_Central_bank_Intervention_rate_policy_interest_rate  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)                                           0.125000
# (2010-04-01 00:00:00, 2010-10-01)                                           0.125000
# (2010-07-01 00:00:00, 2011-01-01)                                           0.125000
# (2010-10-01 00:00:00, 2011-04-01)                                           0.125000
# (2011-01-01 00:00:00, 2011-07-01)                                           0.125000
# (2011-04-01 00:00:00, 2011-10-01)                                           0.125000
# (2011-07-01 00:00:00, 2012-01-01)                                           0.125000
# (2011-10-01 00:00:00, 2012-04-01)                                           0.125000
# (2012-01-01 00:00:00, 2012-07-01)                                           0.125000
# (2012-04-01 00:00:00, 2012-10-01)                                           0.125000
# (2012-07-01 00:00:00, 2013-01-01)                                           0.125000
# (2012-10-01 00:00:00, 2013-04-01)                                           0.125000
# (2013-01-01 00:00:00, 2013-07-01)                                           0.125000
# (2013-04-01 00:00:00, 2013-10-01)                                           0.125000
# (2013-07-01 00:00:00, 2014-01-01)                                           0.125000
# (2013-10-01 00:00:00, 2014-04-01)                                           0.125000
# (2014-01-01 00:00:00, 2014-07-01)                                           0.125000
# (2014-04-01 00:00:00, 2014-10-01)                                           0.125000
# (2014-07-01 00:00:00, 2015-01-01)                                           0.125000
# (2014-10-01 00:00:00, 2015-04-01)                                           0.125000
# (2015-01-01 00:00:00, 2015-07-01)                                           0.125000
# (2015-04-01 00:00:00, 2015-10-01)                                           0.125000
# (2015-07-01 00:00:00, 2016-01-01)                                           0.125000
# (2015-10-01 00:00:00, 2016-04-01)                                           0.208333
# (2016-01-01 00:00:00, 2016-07-01)                                           0.375000
# (2016-04-01 00:00:00, 2016-10-01)                                           0.375000
# (2016-07-01 00:00:00, 2017-01-01)                                           0.375000
# (2016-10-01 00:00:00, 2017-04-01)                                           0.458333
# (2017-01-01 00:00:00, 2017-07-01)                                           0.708333
# (2017-04-01 00:00:00, 2017-10-01)                                           0.958333
# (2017-07-01 00:00:00, 2018-01-01)                                           1.125000
# (2017-10-01 00:00:00, 2018-04-01)                                           1.208333
# (2018-01-01 00:00:00, 2018-07-01)                                           1.458333
# (2018-04-01 00:00:00, 2018-10-01)                                           1.708333
# (2018-07-01 00:00:00, 2019-01-01)                                           1.958333
# (2018-10-01 00:00:00, 2019-04-01)                                           2.208333
# (2019-01-01 00:00:00, 2019-07-01)                                           2.375000
# (2019-04-01 00:00:00, 2019-10-01)                                           2.375000
# (2019-07-01 00:00:00, 2020-01-01)                                           2.125000
# (2019-10-01 00:00:00, 2020-04-01)                                           1.625000
# (2020-01-01 00:00:00, 2020-07-01)                                           1.125000
# (2020-04-01 00:00:00, 2020-10-01)                                           0.125000
# (2020-07-01 00:00:00, 2021-01-01)                                           0.125000
# (2020-10-01 00:00:00, 2021-04-01)                                           0.125000
# (2021-01-01 00:00:00, 2021-07-01)                                           0.125000
# (2021-04-01 00:00:00, 2021-10-01)                                           0.125000
# (2021-07-01 00:00:00, 2022-01-01)                                           0.125000
# (2021-10-01 00:00:00, 2022-04-01)                                           0.125000
# (2022-01-01 00:00:00, 2022-07-01)                                           0.208333
# (2022-04-01 00:00:00, 2022-10-01)                                           0.958333
# (2022-07-01 00:00:00, 2023-01-01)                                           2.625000
# (2022-10-01 00:00:00, 2023-04-01)                                           3.791667
#
#                                    US_Effective_exchange_rate  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)                   84.740000
# (2010-04-01 00:00:00, 2010-10-01)                   86.106667
# (2010-07-01 00:00:00, 2011-01-01)                   84.923333
# (2010-10-01 00:00:00, 2011-04-01)                   81.390000
# (2011-01-01 00:00:00, 2011-07-01)                   80.343333
# (2011-04-01 00:00:00, 2011-10-01)                   78.926667
# (2011-07-01 00:00:00, 2012-01-01)                   79.426667
# (2011-10-01 00:00:00, 2012-04-01)                   81.786667
# (2012-01-01 00:00:00, 2012-07-01)                   81.180000
# (2012-04-01 00:00:00, 2012-10-01)                   82.923333
# (2012-07-01 00:00:00, 2013-01-01)                   82.833333
# (2012-10-01 00:00:00, 2013-04-01)                   81.100000
# (2013-01-01 00:00:00, 2013-07-01)                   81.450000
# (2013-04-01 00:00:00, 2013-10-01)                   82.413333
# (2013-07-01 00:00:00, 2014-01-01)                   83.213333
# (2013-10-01 00:00:00, 2014-04-01)                   81.956667
# (2014-01-01 00:00:00, 2014-07-01)                   83.110000
# (2014-04-01 00:00:00, 2014-10-01)                   83.216667
# (2014-07-01 00:00:00, 2015-01-01)                   83.793333
# (2014-10-01 00:00:00, 2015-04-01)                   86.503333
# (2015-01-01 00:00:00, 2015-07-01)                   90.813333
# (2015-04-01 00:00:00, 2015-10-01)                   91.950000
# (2015-07-01 00:00:00, 2016-01-01)                   94.870000
# (2015-10-01 00:00:00, 2016-04-01)                   95.663333
# (2016-01-01 00:00:00, 2016-07-01)                   97.276667
# (2016-04-01 00:00:00, 2016-10-01)                   95.586667
# (2016-07-01 00:00:00, 2017-01-01)                   96.483333
# (2016-10-01 00:00:00, 2017-04-01)                   99.403333
# (2017-01-01 00:00:00, 2017-07-01)                  100.160000
# (2017-04-01 00:00:00, 2017-10-01)                   97.846667
# (2017-07-01 00:00:00, 2018-01-01)                   94.440000
# (2017-10-01 00:00:00, 2018-04-01)                   94.813333
# (2018-01-01 00:00:00, 2018-07-01)                   92.190000
# (2018-04-01 00:00:00, 2018-10-01)                   94.880000
# (2018-07-01 00:00:00, 2019-01-01)                   97.470000
# (2018-10-01 00:00:00, 2019-04-01)                   98.583333
# (2019-01-01 00:00:00, 2019-07-01)                   97.400000
# (2019-04-01 00:00:00, 2019-10-01)                   98.633333
# (2019-07-01 00:00:00, 2020-01-01)                   99.490000
# (2019-10-01 00:00:00, 2020-04-01)                   98.810000
# (2020-01-01 00:00:00, 2020-07-01)                   99.610000
# (2020-04-01 00:00:00, 2020-10-01)                  103.363333
# (2020-07-01 00:00:00, 2021-01-01)                  100.143333
# (2020-10-01 00:00:00, 2021-04-01)                   96.880000
# (2021-01-01 00:00:00, 2021-07-01)                   95.456667
# (2021-04-01 00:00:00, 2021-10-01)                   96.743333
# (2021-07-01 00:00:00, 2022-01-01)                   98.673333
# (2021-10-01 00:00:00, 2022-04-01)                  100.276667
# (2022-01-01 00:00:00, 2022-07-01)                  101.383333
# (2022-04-01 00:00:00, 2022-10-01)                  105.586667
# (2022-07-01 00:00:00, 2023-01-01)                  109.716667
# (2022-10-01 00:00:00, 2023-04-01)                  110.203333
#
#                                    US_Equity_prices  US_GDP_Growth_Rate  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)         46.875171            0.484501
# (2010-04-01 00:00:00, 2010-10-01)         41.314746            0.967586
# (2010-07-01 00:00:00, 2011-01-01)         45.743602            0.771085
# (2022-01-01 00:00:00, 2022-07-01)        181.595940           -0.257454
# (2022-04-01 00:00:00, 2022-10-01)        151.732314            0.070179
# (2022-07-01 00:00:00, 2023-01-01)        143.725189            0.673208
# (2022-10-01 00:00:00, 2023-04-01)        153.901653            0.827828
#
#                                    US_House_prices_residential  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)                    94.481014
# (2010-04-01 00:00:00, 2010-10-01)                    93.876843
# (2010-07-01 00:00:00, 2011-01-01)                    92.137491
# (2010-10-01 00:00:00, 2011-04-01)                    90.641295
# (2011-01-01 00:00:00, 2011-07-01)                    87.908116
# (2011-04-01 00:00:00, 2011-10-01)                    86.310846
# (2011-07-01 00:00:00, 2012-01-01)                    86.167368
# (2011-10-01 00:00:00, 2012-04-01)                    86.049087
# (2012-01-01 00:00:00, 2012-07-01)                    85.850160
# (2012-04-01 00:00:00, 2012-10-01)                    87.004029
# (2012-07-01 00:00:00, 2013-01-01)                    87.820165
# (2012-10-01 00:00:00, 2013-04-01)                    88.641539
# (2013-01-01 00:00:00, 2013-07-01)                    90.148565
# (2013-04-01 00:00:00, 2013-10-01)                    91.913178
# (2013-07-01 00:00:00, 2014-01-01)                    92.975050
# (2013-10-01 00:00:00, 2014-04-01)                    93.546325
# (2014-01-01 00:00:00, 2014-07-01)                    94.243745
# (2014-04-01 00:00:00, 2014-10-01)                    94.658214
# (2014-07-01 00:00:00, 2015-01-01)                    95.432840
# (2014-10-01 00:00:00, 2015-04-01)                    96.799536
# (2015-01-01 00:00:00, 2015-07-01)                    98.574308
# (2015-04-01 00:00:00, 2015-10-01)                    99.328341
# (2015-07-01 00:00:00, 2016-01-01)                   100.298414
# (2015-10-01 00:00:00, 2016-04-01)                   101.798937
# (2016-01-01 00:00:00, 2016-07-01)                   103.014533
# (2016-04-01 00:00:00, 2016-10-01)                   103.853380
# (2016-07-01 00:00:00, 2017-01-01)                   105.040393
# (2016-10-01 00:00:00, 2017-04-01)                   106.194643
# (2017-01-01 00:00:00, 2017-07-01)                   106.941431
# (2017-04-01 00:00:00, 2017-10-01)                   108.570540
# (2017-07-01 00:00:00, 2018-01-01)                   109.857003
# (2017-10-01 00:00:00, 2018-04-01)                   110.830106
# (2018-01-01 00:00:00, 2018-07-01)                   112.129171
# (2018-04-01 00:00:00, 2018-10-01)                   112.842441
# (2018-07-01 00:00:00, 2019-01-01)                   113.928901
# (2018-10-01 00:00:00, 2019-04-01)                   114.762234
# (2019-01-01 00:00:00, 2019-07-01)                   115.884367
# (2019-04-01 00:00:00, 2019-10-01)                   116.625999
# (2019-07-01 00:00:00, 2020-01-01)                   117.875588
# (2019-10-01 00:00:00, 2020-04-01)                   119.382220
# (2020-01-01 00:00:00, 2020-07-01)                   121.333352
# (2020-04-01 00:00:00, 2020-10-01)                   122.603304
# (2020-07-01 00:00:00, 2021-01-01)                   126.156829
# (2020-10-01 00:00:00, 2021-04-01)                   131.175429
# (2021-01-01 00:00:00, 2021-07-01)                   134.400201
# (2021-04-01 00:00:00, 2021-10-01)                   138.336392
# (2021-07-01 00:00:00, 2022-01-01)                   142.703324
# (2021-10-01 00:00:00, 2022-04-01)                   145.871283
# (2022-01-01 00:00:00, 2022-07-01)                   148.934617
# (2022-04-01 00:00:00, 2022-10-01)                   150.879826
# (2022-07-01 00:00:00, 2023-01-01)                   148.936829
# (2022-10-01 00:00:00, 2023-04-01)                   147.980572
#
#                                    US_Inflation_rate  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)           2.360525
# (2010-04-01 00:00:00, 2010-10-01)           1.767765
# (2010-07-01 00:00:00, 2011-01-01)           1.175609
# (2010-10-01 00:00:00, 2011-04-01)           1.270248
# (2011-01-01 00:00:00, 2011-07-01)           2.141127
# (2011-04-01 00:00:00, 2011-10-01)           3.430395
# (2011-07-01 00:00:00, 2012-01-01)           3.756174
# (2011-10-01 00:00:00, 2012-04-01)           3.293777
# (2012-01-01 00:00:00, 2012-07-01)           2.815192
# (2012-04-01 00:00:00, 2012-10-01)           1.889765
# (2012-07-01 00:00:00, 2013-01-01)           1.697784
# (2012-10-01 00:00:00, 2013-04-01)           1.889365
# (2013-01-01 00:00:00, 2013-07-01)           1.681829
# (2013-04-01 00:00:00, 2013-10-01)           1.392850
# (2013-07-01 00:00:00, 2014-01-01)           1.553359
# (2013-10-01 00:00:00, 2014-04-01)           1.233471
# (2014-01-01 00:00:00, 2014-07-01)           1.405456
# (2014-04-01 00:00:00, 2014-10-01)           2.050846
# (2014-07-01 00:00:00, 2015-01-01)           1.783154
# (2014-10-01 00:00:00, 2015-04-01)           1.248028
# (2015-01-01 00:00:00, 2015-07-01)          -0.062696
# (2015-04-01 00:00:00, 2015-10-01)          -0.038272
# (2015-07-01 00:00:00, 2016-01-01)           0.109503
# (2015-10-01 00:00:00, 2016-04-01)           0.466265
# (2016-01-01 00:00:00, 2016-07-01)           1.080267
# (2016-04-01 00:00:00, 2016-10-01)           1.047063
# (2016-07-01 00:00:00, 2017-01-01)           1.117615
# (2016-10-01 00:00:00, 2017-04-01)           1.800621
# (2017-01-01 00:00:00, 2017-07-01)           2.539320
# (2017-04-01 00:00:00, 2017-10-01)           1.901991
# (2017-07-01 00:00:00, 2018-01-01)           1.966925
# (2017-10-01 00:00:00, 2018-04-01)           2.117558
# (2018-01-01 00:00:00, 2018-07-01)           2.214195
# (2018-04-01 00:00:00, 2018-10-01)           2.711887
# (2018-07-01 00:00:00, 2019-01-01)           2.640940
# (2018-10-01 00:00:00, 2019-04-01)           2.203131
# (2019-01-01 00:00:00, 2019-07-01)           1.644936
# (2019-04-01 00:00:00, 2019-10-01)           1.811376
# (2019-07-01 00:00:00, 2020-01-01)           1.757488
# (2019-10-01 00:00:00, 2020-04-01)           2.032914
# (2020-01-01 00:00:00, 2020-07-01)           2.118652
# (2020-04-01 00:00:00, 2020-10-01)           0.364296
# (2020-07-01 00:00:00, 2021-01-01)           1.222386
# (2020-10-01 00:00:00, 2021-04-01)           1.239488
# (2021-01-01 00:00:00, 2021-07-01)           1.898514
# (2021-04-01 00:00:00, 2021-10-01)           4.848945
# (2021-07-01 00:00:00, 2022-01-01)           5.335693
# (2021-10-01 00:00:00, 2022-04-01)           6.689106
# (2022-01-01 00:00:00, 2022-07-01)           7.964464
# (2022-04-01 00:00:00, 2022-10-01)           8.633300
# (2022-07-01 00:00:00, 2023-01-01)           8.329726
# (2022-10-01 00:00:00, 2023-04-01)           7.103384
#
#                                    US_Long_term_interest_rate  US_Oil_price  \
# quarter
# (2010-01-01 00:00:00, 2010-07-01)                    3.716667     76.674837
# (2010-04-01 00:00:00, 2010-10-01)                    3.490000     78.845036
# (2010-07-01 00:00:00, 2011-01-01)                    2.786667     76.675000
# (2010-10-01 00:00:00, 2011-04-01)                    2.863333     87.033160
# (2011-01-01 00:00:00, 2011-07-01)                    3.460000    105.369424
# (2011-04-01 00:00:00, 2011-10-01)                    3.210000    117.541905
# (2011-07-01 00:00:00, 2012-01-01)                    2.426667    113.266948
# (2011-10-01 00:00:00, 2012-04-01)                    2.046667    109.978629
# (2012-01-01 00:00:00, 2012-07-01)                    2.036667    118.427965
# (2012-04-01 00:00:00, 2012-10-01)                    1.823333    109.060407
# (2012-07-01 00:00:00, 2013-01-01)                    1.643333    110.133827
# (2012-10-01 00:00:00, 2013-04-01)                    1.706667    110.424491
# (2013-01-01 00:00:00, 2013-07-01)                    1.950000    112.867180
# (2013-04-01 00:00:00, 2013-10-01)                    1.996667    103.099645
# (2013-07-01 00:00:00, 2014-01-01)                    2.710000    110.266868
# (2013-10-01 00:00:00, 2014-04-01)                    2.746667    109.613209
# (2014-01-01 00:00:00, 2014-07-01)                    2.763333    108.211017
# (2014-04-01 00:00:00, 2014-10-01)                    2.623333    110.025620
# (2014-07-01 00:00:00, 2015-01-01)                    2.496667    102.572414
# (2014-10-01 00:00:00, 2015-04-01)                    2.280000     76.572732
# (2015-01-01 00:00:00, 2015-07-01)                    1.966667     54.570576
# (2015-04-01 00:00:00, 2015-10-01)                    2.166667     62.546724
# (2015-07-01 00:00:00, 2016-01-01)                    2.220000     50.797943
# (2015-10-01 00:00:00, 2016-04-01)                    2.190000     44.175606
# (2016-01-01 00:00:00, 2016-07-01)                    1.920000     35.199931
# (2016-04-01 00:00:00, 2016-10-01)                    1.753333     46.980916
# (2016-07-01 00:00:00, 2017-01-01)                    1.563333     47.009188
# (2016-10-01 00:00:00, 2017-04-01)                    2.130000     51.126270
# (2017-01-01 00:00:00, 2017-07-01)                    2.443333     54.820709
# (2017-04-01 00:00:00, 2017-10-01)                    2.263333     51.001692
# (2017-07-01 00:00:00, 2018-01-01)                    2.243333     52.246259
# (2017-10-01 00:00:00, 2018-04-01)                    2.370000     61.479004
# (2018-01-01 00:00:00, 2018-07-01)                    2.760000     67.159150
# (2018-04-01 00:00:00, 2018-10-01)                    2.920000     74.890021
# (2018-07-01 00:00:00, 2019-01-01)                    2.926667     76.081132
# (2018-10-01 00:00:00, 2019-04-01)                    3.033333     68.320070
# (2019-01-01 00:00:00, 2019-07-01)                    2.653333     63.756896
# (2017-04-01 00:00:00, 2017-10-01)              4.366667  0.110625
# (2017-07-01 00:00:00, 2018-01-01)              4.333333  0.341075
# (2017-10-01 00:00:00, 2018-04-01)              4.166667  0.280355
# (2018-01-01 00:00:00, 2018-07-01)              4.033333  0.359940
# (2018-04-01 00:00:00, 2018-10-01)              3.933333 -0.471350
# (2018-07-01 00:00:00, 2019-01-01)              3.766667 -0.962522
# (2018-10-01 00:00:00, 2019-04-01)              3.833333 -1.927952
# (2019-01-01 00:00:00, 2019-07-01)              3.866667 -1.788685
# (2019-04-01 00:00:00, 2019-10-01)              3.633333 -1.663545
# (2019-07-01 00:00:00, 2020-01-01)              3.600000 -1.105886
# (2019-10-01 00:00:00, 2020-04-01)              3.600000  0.092922
# (2020-01-01 00:00:00, 2020-07-01)              3.833333  0.734780
# (2020-04-01 00:00:00, 2020-10-01)             13.000000  1.435027
# (2020-07-01 00:00:00, 2021-01-01)              8.800000  1.531983
# (2020-10-01 00:00:00, 2021-04-01)              6.733333  1.339270
# (2021-01-01 00:00:00, 2021-07-01)              6.233333  0.823792
# (2021-04-01 00:00:00, 2021-10-01)              5.933333 -0.032476
# (2021-07-01 00:00:00, 2022-01-01)              5.066667 -0.030913
# (2021-10-01 00:00:00, 2022-04-01)              4.166667  0.223604
# (2022-01-01 00:00:00, 2022-07-01)              3.833333 -0.395155
# (2022-04-01 00:00:00, 2022-10-01)              3.633333 -0.750896
# (2022-07-01 00:00:00, 2023-01-01)              3.533333 -0.364328
# (2022-10-01 00:00:00, 2023-04-01)              3.566667 -1.696752

# %%
df_full.index = pd.to_datetime([x[0] for x in df_full.index]).normalize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df_full.index = pd.to_datetime(df_full.index).normalize()
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1081, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1079         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#    1080     else:
# -> 1081         result = convert_listlike(arg, format, name=arg.name)
#    1082 elif is_list_like(arg):
#    1083     try:
#    1084         # error: Argument 1 to "_maybe_cache" has incompatible type
#    1085         # "Union[float, str, datetime, List[Any], Tuple[Any, ...], ExtensionArray,
#    1086         # ndarray[Any, Any], Series]"; expected "Union[List[Any], Tuple[Any, ...],
#    1087         # Union[Union[ExtensionArray, ndarray[Any, Any]], Index, Series], Series]"
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimes.py:2415, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2412 # if str-dtype, convert
#    2413 data = np.asarray(data, dtype=np.object_)
# -> 2415 result, tz_parsed = tslib.array_to_datetime(
#    2416     data,
#    2417     errors=errors,
#    2418     utc=utc,
#    2419     dayfirst=dayfirst,
#    2420     yearfirst=yearfirst,
#    2421     creso=abbrev_to_npy_unit(out_unit),
#    2422 )
#    2424 if tz_parsed is not None:
#    2425     # We can take a shortcut since the datetime64 numpy array
#    2426     #  is in UTC
#    2427     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:412, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:588, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'tuple'> is not convertible to datetime, at position 0

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_full.index, df_full["Zt"], label="Z_Finance")
plt.plot(df_full.index, df_full["US_GDP_Growth_Rate"], label="US_GDP_Growth_Rate")
plt.plot(df_full.index, df_full["US_Unemployment_rate"], label="US_Unemployment_rate")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_full.index, df_full["US_GDP_Growth_Rate"], 
         label="US_GDP_Growth_Rate")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import warnings

from statsmodels.tsa.stattools import adfuller, kpss

def stationarity_tests_summary(
    df: pd.DataFrame,
    variables=None,
    adf_alpha: float = 0.05,
    kpss_alpha: float = 0.05,
    kpss_regression: str = "c",
    autolag: str = "AIC",
    dropna: bool = True,
    min_n: int = 20
) -> pd.DataFrame:
    """
    Calcule ADF + KPSS pour une liste de variables, renvoie un tableau récapitulatif
    avec p-values, décisions à 5% et diagnostic.

    Parameters
    ----------
    df : DataFrame (wide) avec colonnes = variables.
    variables : list[str] ou None (par défaut: toutes les colonnes numériques).
    adf_alpha : seuil de rejet ADF (H0 = non-stationnaire).
    kpss_alpha : seuil de rejet KPSS (H0 = stationnaire).
    kpss_regression : 'c' (stationnaire autour d'une constante) ou 'ct' (constante+tendance).
    autolag : méthode de sélection du lag pour ADF ('AIC','BIC','t-stat',None).
    dropna : supprime les NA avant tests.
    min_n : taille minimale requise pour lancer les tests.

    Returns
    -------
    DataFrame avec colonnes:
    variable, n, adf_pvalue, kpss_pvalue, ADF_stationary_5pct, KPSS_stationary_5pct, diagnosis
    """
    if variables is None:
        # par défaut: toutes les colonnes numériques
        variables = df.select_dtypes(include=[np.number]).columns.tolist()
    else:
        variables = list(variables)

    results = []

    for var in variables:
        if var not in df.columns:
            results.append({
                "variable": var, "n": 0,
                "adf_pvalue": np.nan, "kpss_pvalue": np.nan,
                "ADF_stationary_5pct": np.nan, "KPSS_stationary_5pct": np.nan,
                "diagnosis": "Missing"
            })
            continue

        s = df[var]
        s = s.dropna() if dropna else s

        # Cast float (évite certains soucis)
        s = pd.to_numeric(s, errors="coerce").dropna()

        n = len(s)

        # Cas série trop courte / constante
        if n < min_n or s.nunique() <= 1:
            results.append({
                "variable": var, "n": n,
                "adf_pvalue": np.nan, "kpss_pvalue": np.nan,
                "ADF_stationary_5pct": np.nan, "KPSS_stationary_5pct": np.nan,
                "diagnosis": "Insufficient/Constant"
            })
            continue

        # -------- ADF --------
        adf_p = np.nan
        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                adf_out = adfuller(s.values, autolag=autolag)
            adf_p = float(adf_out[1])
        except Exception:
            adf_p = np.nan

        # -------- KPSS --------
        kpss_p = np.nan
        try:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                kpss_out = kpss(s.values, regression=kpss_regression, nlags="auto")
            kpss_p = float(kpss_out[1])
        except Exception:
            kpss_p = np.nan

        # Décisions
        # ADF: rejeter H0 (non-stationnaire) si p < alpha => stationnaire
        adf_stationary = (adf_p < adf_alpha) if not np.isnan(adf_p) else np.nan
        # KPSS: rejeter H0 (stationnaire) si p < alpha => non stationnaire
        # donc stationnaire si p > alpha
        kpss_stationary = (kpss_p > kpss_alpha) if not np.isnan(kpss_p) else np.nan

        # Diagnostic combiné
        if adf_stationary is True and kpss_stationary is True:
            diag = "Stationary"
        elif adf_stationary is False and kpss_stationary is False:
            diag = "Non-stationary"
        elif (adf_stationary is np.nan) or (kpss_stationary is np.nan):
            diag = "Test failed"
        else:
            diag = "Ambiguous"

        results.append({
            "variable": var,
            "n": n,
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_stationary,
            "KPSS_stationary_5pct": kpss_stationary,
            "diagnosis": diag
        })

    out = pd.DataFrame(results)

    # Optionnel: trier pour lecture (Non-stationary / Ambiguous / Stationary)
    order = pd.CategoricalDtype(
        categories=["Non-stationary", "Ambiguous", "Stationary", "Insufficient/Constant", "Missing", "Test failed"],
        ordered=True
    )
    if "diagnosis" in out.columns:
        out["diagnosis"] = out["diagnosis"].astype(order)

    return out

# %%
variables = df_full.columns.tolist()[1:]

# %%
variables
# Out:
# ['US_Central_bank_Intervention_rate_policy_interest_rate',
#  'US_Effective_exchange_rate',
#  'US_Equity_prices',
#  'US_GDP_Growth_Rate',
#  'US_House_prices_residential',
#  'US_Inflation_rate',
#  'US_Long_term_interest_rate',
#  'US_Oil_price',
#  'US_Unemployment_rate',
#  'quarter',
#  'Zt']

# %%
variables = df_full.columns.drop("quarter")# toutes sauf "quarter"
stationarity_df = stationarity_tests_summary(df_full, variables)
stationarity_df
# Out:
#                                             variable   n    adf_pvalue  \
# 0  US_Central_bank_Intervention_rate_policy_inter...  52  9.981144e-01
# 1                         US_Effective_exchange_rate  52  9.348144e-01
# 2                                   US_Equity_prices  52  9.989686e-01
# 3                                 US_GDP_Growth_Rate  52  4.232049e-16
# 4                        US_House_prices_residential  52  9.966748e-01
# 5                                  US_Inflation_rate  52  8.172107e-01
# 6                         US_Long_term_interest_rate  52  4.257016e-03
# 7                                       US_Oil_price  52  3.824774e-01
# 8                               US_Unemployment_rate  52  8.609981e-02
# 9                                                 Zt  52  7.063579e-03
#
#    kpss_pvalue  ADF_stationary_5pct  KPSS_stationary_5pct       diagnosis
# 0     0.040597                False                 False  Non-stationary
# 1     0.010000                False                 False  Non-stationary
# 2     0.010000                False                 False  Non-stationary
# 3     0.100000                 True                  True      Stationary
# 4     0.010000                False                 False  Non-stationary
# 5     0.068039                False                  True       Ambiguous
# 6     0.100000                 True                  True      Stationary
# 7     0.070464                False                  True       Ambiguous
# 8     0.013845                False                 False  Non-stationary
# 9     0.100000                 True                  True      Stationary

# %% [markdown]
# ## Stationnarité des variables macroéconomiques et transformations retenues
#
# Les tests de stationnarité ADF et KPSS appliqués aux variables macroéconomiques indiquent que la majorité des séries en niveau sont non stationnaires, ce qui est conforme aux propriétés empiriques bien documentées des séries macroéconomiques. Afin d’éviter toute régression fallacieuse dans la modélisation satellite, ces variables sont transformées de manière appropriée pour assurer leur stationnarité avant estimation.
#
# Les transformations retenues s’appuient sur les pratiques standards en économétrie appliquée et en modélisation du risque de crédit, en tenant compte de la nature économique de chaque variable.
#
# ---
#
# ### 🔹 Taux d’intérêt de la Banque Centrale
# **Transformation : différence première**
#
# Les taux directeurs présentent généralement des comportements persistants, marqués par des régimes de politique monétaire successifs. Leur niveau est souvent non stationnaire, tandis que leurs variations capturent les décisions discrétionnaires des banques centrales.
#
# \[
# \Delta r_t = r_t - r_{t-1}
# \]
#
# ---
#
# ### 🔹 Taux d’intérêt à long terme
# **Transformation : différence première**
#
# Les taux longs reflètent les anticipations de croissance et d’inflation à long terme et sont susceptibles de contenir une tendance stochastique. La différenciation permet d’isoler les variations conjoncturelles pertinentes pour le risque de crédit.
#
# ---
#
# ### 🔹 Taux de chômage
# **Transformation : différence première**
#
# Le taux de chômage est une variable structurelle, caractérisée par une forte inertie. La différenciation permet de capturer les variations du marché du travail, plus directement liées aux cycles économiques.
#
# ---
#
# ### 🔹 Taux d’inflation (États-Unis)
# **Transformation : différence première**
#
# Bien que l’inflation soit parfois stationnaire selon la période considérée, elle peut présenter des ruptures de régime. La différenciation est retenue par prudence afin de garantir la stationnarité.
#
# ---
#
# ### 🔹 Produit Intérieur Brut (PIB)
# **Transformation : variation logarithmique (log-ratio)**
#
# Le PIB est une variable strictement croissante à long terme. La transformation logarithmique en taux de croissance permet d’obtenir une série stationnaire, interprétable comme une croissance économique.
#
# \[
# \Delta \log(Y_t) = \log(Y_t) - \log(Y_{t-1})
# \]
#
# ---
#
# ### 🔹 Taux de change effectif
# **Transformation : variation logarithmique (log-ratio)**
#
# Les taux de change sont modélisés comme des processus intégrés. La variation logarithmique permet de capturer les rendements de change, généralement stationnaires.
#
# ---
#
# ### 🔹 Prix du marché boursier (États-Unis)
# **Transformation : variation logarithmique (log-ratio)**
#
# Les indices boursiers présentent une tendance de long terme liée à la croissance économique et à l’inflation. Les rendements logarithmiques constituent une représentation stationnaire et économiquement interprétable.
#
# ---
#
# ### 🔹 Prix de l’immobilier résidentiel (États-Unis)
# **Transformation : variation logarithmique (log-ratio)**
#
# Les prix immobiliers suivent des dynamiques de long terme avec des cycles marqués. La transformation en rendements logarithmiques permet de neutraliser la tendance et de capter les fluctuations cycliques.
#
# ---
#
# ### 🔹 Prix du pétrole (États-Unis)
# **Transformation : variation logarithmique (log-ratio)**
#
# Les prix des matières premières sont volatils et souvent non stationnaires en niveau. Les variations logarithmiques sont privilégiées afin de modéliser les chocs de prix de manière stationnaire.
#
# ---
#
# ### Conclusion
#
# À l’issue de ces transformations, l’ensemble des variables macroéconomiques utilisées dans la modélisation satellite satisfait les conditions de stationnarité requises pour l’estimation de modèles linéaires. Les facteurs systémiques sectoriels, déjà stationnaires en niveau, sont conservés sans transformation supplémentaire.

# %%
df_filtre = df_full.copy()

# %%
df_full
# Out:
#       quarter  US_Central_bank_Intervention_rate_policy_interest_rate  \
# 0  2010-01-01                                           0.125000
# 1  2010-04-01                                           0.125000
# 2  2010-07-01                                           0.125000
# 3  2010-10-01                                           0.125000
# 4  2011-01-01                                           0.125000
# 5  2011-04-01                                           0.125000
# 6  2011-07-01                                           0.125000
# 7  2011-10-01                                           0.125000
# 8  2012-01-01                                           0.125000
# 9  2012-04-01                                           0.125000
# 10 2012-07-01                                           0.125000
# 11 2012-10-01                                           0.125000
# 12 2013-01-01                                           0.125000
# 13 2013-04-01                                           0.125000
# 14 2013-07-01                                           0.125000
# 15 2013-10-01                                           0.125000
# 16 2014-01-01                                           0.125000
# 17 2014-04-01                                           0.125000
# 18 2014-07-01                                           0.125000
# 19 2014-10-01                                           0.125000
# 20 2015-01-01                                           0.125000
# 21 2015-04-01                                           0.125000
# 22 2015-07-01                                           0.125000
# 23 2015-10-01                                           0.208333
# 24 2016-01-01                                           0.375000
# 25 2016-04-01                                           0.375000
# 26 2016-07-01                                           0.375000
# 27 2016-10-01                                           0.458333
# 28 2017-01-01                                           0.708333
# 29 2017-04-01                                           0.958333
# 30 2017-07-01                                           1.125000
# 31 2017-10-01                                           1.208333
# 32 2018-01-01                                           1.458333
# 33 2018-04-01                                           1.708333
# 34 2018-07-01                                           1.958333
# 35 2018-10-01                                           2.208333
# 36 2019-01-01                                           2.375000
# 37 2019-04-01                                           2.375000
# 38 2019-07-01                                           2.125000
# 39 2019-10-01                                           1.625000
# 40 2020-01-01                                           1.125000
# 41 2020-04-01                                           0.125000
# 42 2020-07-01                                           0.125000
# 43 2020-10-01                                           0.125000
# 44 2021-01-01                                           0.125000
# 45 2021-04-01                                           0.125000
# 46 2021-07-01                                           0.125000
# 47 2021-10-01                                           0.125000
# 48 2022-01-01                                           0.208333
# 49 2022-04-01                                           0.958333
# 50 2022-07-01                                           2.625000
# 51 2022-10-01                                           3.791667
#
#     US_Effective_exchange_rate  US_Equity_prices  US_GDP_Growth_Rate  \
# 0                    84.740000         46.875171            0.484501
# 1                    86.106667         41.314746            0.967586
# 2                    84.923333         45.743602            0.771085
# 3                    81.390000         50.410959            0.525110
# 4                    80.343333         53.144269           -0.237205
# 5                    78.926667         52.936237            0.676582
# 6                    79.426667         45.351586           -0.022313
# 7                    81.786667         50.409354            1.123049
# 8                    81.180000         56.456793            0.838591
# 9                    82.923333         54.600516            0.446335
# 10                   82.833333         57.747493            0.144028
# 11                   81.100000         57.167076            0.115641
# 12                   81.450000         62.899056            0.986561
# 13                   82.413333         64.385767            0.267636
# 14                   83.213333         67.402873            0.851394
# 15                   81.956667         74.089245            0.871742
# 16                   83.110000         75.050453           -0.345096
# 17                   83.216667         78.573417            1.291842
# 18                   83.793333         79.056830            1.215391
# 19                   86.503333         82.528480            0.505733
# 20                   90.813333         82.888833            0.900485
# 21                   91.950000         82.697241            0.619405
# 22                   94.870000         76.962051            0.400245
# 23                   95.663333         81.928828            0.184479
# 24                   97.276667         82.562154            0.579519
# 25                   95.586667         84.130236            0.321124
# 26                   96.483333         86.912447            0.709390
# 27                   99.403333         89.740760            0.554299
# 28                  100.160000         94.706735            0.486890
# 29                   97.846667         97.139417            0.559873
# 30                   94.440000        100.985463            0.788524
# 31                   94.813333        107.168385            1.127047
# 32                   92.190000        105.856043            0.813410
# 33                   94.880000        108.962535            0.530825
# 34                   97.470000        116.803317            0.623697
# 35                   98.583333        100.484015            0.141644
# 36                   97.400000        113.613447            0.624318
# 37                   98.633333        117.916845            0.835146
# 38                   99.490000        119.318975            1.170002
# 39                   98.810000        129.501859            0.681878
# 40                   99.610000        103.600127           -1.392441
# 41                  103.363333        124.271327           -7.908965
# 42                  100.143333        134.801734            7.830225
# 43                   96.880000        150.557466            1.084726
# 44                   95.456667        159.248423            1.380186
# 45                   96.743333        172.260022            1.570045
# 46                   98.673333        172.662464            0.852849
# 47                  100.276667        191.549536            1.803159
# 48                  101.383333        181.595940           -0.257454
# 49                  105.586667        151.732314            0.070179
# 50                  109.716667        143.725189            0.673208
# 51                  110.203333        153.901653            0.827828
#
#     US_House_prices_residential  US_Inflation_rate  \
# 0                     94.481014           2.360525
# 1                     93.876843           1.767765
# 2                     92.137491           1.175609
# 3                     90.641295           1.270248
# 4                     87.908116           2.141127
# 5                     86.310846           3.430395
# 6                     86.167368           3.756174
# 7                     86.049087           3.293777
# 8                     85.850160           2.815192
# 9                     87.004029           1.889765
# 10                    87.820165           1.697784
# 11                    88.641539           1.889365
# 12                    90.148565           1.681829
# 13                    91.913178           1.392850
# 14                    92.975050           1.553359
# 15                    93.546325           1.233471
# 16                    94.243745           1.405456
# 17                    94.658214           2.050846
# 18                    95.432840           1.783154
# 19                    96.799536           1.248028
# 20                    98.574308          -0.062696
# 21                    99.328341          -0.038272
# 22                   100.298414           0.109503
# 23                   101.798937           0.466265
# 24                   103.014533           1.080267
# 25                   103.853380           1.047063
# 26                   105.040393           1.117615
# 27                   106.194643           1.800621
# 28                   106.941431           2.539320
# 29                   108.570540           1.901991
# 30                   109.857003           1.966925
# 31                   110.830106           2.117558
# 32                   112.129171           2.214195
# 33                   112.842441           2.711887
# 34                   113.928901           2.640940
# 35                   114.762234           2.203131
# 36                   115.884367           1.644936
# 37                   116.625999           1.811376
# 38                   117.875588           1.757488
# 39                   119.382220           2.032914
# 40                   121.333352           2.118652
# 41                   122.603304           0.364296
# 42                   126.156829           1.222386
# 43                   131.175429           1.239488
# 44                   134.400201           1.898514
# 45                   138.336392           4.848945
# 46                   142.703324           5.335693
# 47                   145.871283           6.689106
# 48                   148.934617           7.964464
# 49                   150.879826           8.633300
# 50                   148.936829           8.329726
# 51                   147.980572           7.103384
#
#     US_Long_term_interest_rate  US_Oil_price  US_Unemployment_rate  \
# 30  2018-01-01  0.341075
# 31  2018-04-01  0.280355
# 32  2018-07-01  0.359940
# 33  2018-10-01 -0.471350
# 34  2019-01-01 -0.962522
# 35  2019-04-01 -1.927952
# 36  2019-07-01 -1.788685
# 37  2019-10-01 -1.663545
# 38  2020-01-01 -1.105886
# 39  2020-04-01  0.092922
# 40  2020-07-01  0.734780
# 41  2020-10-01  1.435027
# 42  2021-01-01  1.531983
# 43  2021-04-01  1.339270
# 44  2021-07-01  0.823792
# 45  2021-10-01 -0.032476
# 46  2022-01-01 -0.030913
# 47  2022-04-01  0.223604
# 48  2022-07-01 -0.395155
# 49  2022-10-01 -0.750896
# 50  2023-01-01 -0.364328
# 51  2023-04-01 -1.696752

# %%
df_full=df_filtre.copy()

# %%
import numpy as np
import pandas as pd

TRANSFORMATIONS = {
    # Interest rates -> difference
    "EU_Central_bank_Intervention_rate_policy_interest_rate": "diff",
    "EU_Long_term_interest_rate": "diff",
    "US_Central_bank_Intervention_rate_policy_interest_rate": "diff",
    "US_Long_term_interest_rate": "diff",

    # Unemployment & inflation -> difference
    "EU_Unemployment_rate": "diff",
    "US_Unemployment_rate": "diff",
    "US_Inflation_rate": "diff",

    # Exchange rates -> log ratio
    "EU_Effective_exchange_rate": "log_ratio",
    "US_Effective_exchange_rate": "log_ratio",

    # Prices -> log ratio
    "US_Equity_prices": "log_ratio",
    "US_House_prices_residential": "log_ratio",
    "US_Oil_price": "log_ratio",

    # GDP growth rates -> keep (already stationary in your tests)
    "EU_GDP_Growth_Rate": "level",
    "US_GDP_Growth_Rate": "level",
}

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss

def _adf_kpss(series, regression="c"):
    s = series.dropna()
    if len(s) < 20:
        return np.nan, np.nan  # pas assez de points
    adf_p = adfuller(s, autolag="AIC")[1]
    kpss_p = kpss(s, regression=regression, nlags="auto")[1]
    return adf_p, kpss_p

def _diagnosis(adf_p, kpss_p, alpha=0.05):
    adf_stat = (adf_p < alpha) if pd.notna(adf_p) else False
    kpss_stat = (kpss_p > alpha) if pd.notna(kpss_p) else False
    if adf_stat and kpss_stat:
        return True, True, "Stationary"
    if (not adf_stat) and (not kpss_stat):
        return False, False, "Non-stationary"
    return adf_stat, kpss_stat, "Ambiguous"

def stationarize_and_test(
    df_wide: pd.DataFrame,
    transformations: dict,
    alpha: float = 0.05,
    kpss_regression: str = "c",
    add_prefix: bool = False,
):
    """
    df_wide: index=date (monthly), columns=variables
    transformations: dict {colname: 'level'|'diff'|'log_ratio'}
    add_prefix: if True, columns are renamed e.g. d_EU_rate, lr_US_fx, ...
    """
    df = df_wide.copy()

    # --- sanity check: missing keys / missing columns
    missing_in_df = [k for k in transformations.keys() if k not in df.columns]
    missing_in_dict = [c for c in df.columns if c not in transformations.keys()]

    if missing_in_df:
        print("⚠️ Keys in TRANSFORMATIONS but not in df columns:", missing_in_df)
    if missing_in_dict:
        print("⚠️ Columns in df but not in TRANSFORMATIONS (kept as level):", missing_in_dict)

    # default = level for unspecified columns
    trans = {c: transformations.get(c, "level") for c in df.columns}

    # --- tests BEFORE
    before_rows = []
    for c in df.columns:
        adf_p, kpss_p = _adf_kpss(df[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        before_rows.append({
            "variable": c,
            "transform": "level",
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    before_df = pd.DataFrame(before_rows)

    # --- apply transformations
    out = pd.DataFrame(index=df.index)

    def apply_one(s, how):
        if how == "level":
            return s
        if how == "diff":
            return s.diff()
        if how == "log_ratio":
            # safe log: only for strictly positive series
            s2 = s.replace(0, np.nan)
            return np.log(s2).diff()
        raise ValueError(f"Unknown transformation: {how}")

    rename_map = {}
    for c in df.columns:
        how = trans[c]
        s_tr = apply_one(df[c], how)
        if add_prefix:
            pref = {"level":"", "diff":"d_", "log_ratio":"lr_"}[how]
            new_name = pref + c
        else:
            new_name = c
        out[new_name] = s_tr
        rename_map[c] = new_name

    # --- tests AFTER
    after_rows = []
    for c_old in df.columns:
        c = rename_map[c_old]
        how = trans[c_old]
        adf_p, kpss_p = _adf_kpss(out[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        after_rows.append({
            "variable": c_old,
            "transform": how,
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    after_df = pd.DataFrame(after_rows)

    return out, before_df, after_df

# %%
# df_macro_wide : index = date_q, columns = variables
out, before_df, after_df= stationarize_and_test(df_full.drop(columns=["quarter"]), TRANSFORMATIONS)

df_macro_stationary = after_df
df_macro_stationary
# Out:
# ⚠️ Keys in TRANSFORMATIONS but not in df columns: ['EU_Central_bank_Intervention_rate_policy_interest_rate', 'EU_Long_term_interest_rate', 'EU_Unemployment_rate', 'EU_Effective_exchange_rate', 'EU_GDP_Growth_Rate']
# ⚠️ Columns in df but not in TRANSFORMATIONS (kept as level): ['Zt']
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
#                                             variable  transform    adf_pvalue  \
# 0  US_Central_bank_Intervention_rate_policy_inter...       diff  7.308402e-06
# 1                         US_Effective_exchange_rate  log_ratio  7.762195e-06
# 2                                   US_Equity_prices  log_ratio  4.961131e-14
# 3                                 US_GDP_Growth_Rate      level  4.232049e-16
# 4                        US_House_prices_residential  log_ratio  2.939448e-04
# 5                                  US_Inflation_rate       diff  1.278346e-01
# 6                         US_Long_term_interest_rate       diff  2.210028e-04
# 7                                       US_Oil_price  log_ratio  2.466993e-07
# 8                               US_Unemployment_rate       diff  3.072724e-14
# 9                                                 Zt      level  7.063579e-03
#
#    kpss_pvalue  ADF_stationary_5pct  KPSS_stationary_5pct   diagnosis
# 0     0.100000                 True                  True  Stationary
# 1     0.100000                 True                  True  Stationary
# 2     0.100000                 True                  True  Stationary
# 3     0.100000                 True                  True  Stationary
# 4     0.047688                 True                 False   Ambiguous
# 5     0.100000                False                  True   Ambiguous
# 6     0.100000                 True                  True  Stationary
# 7     0.100000                 True                  True  Stationary
# 8     0.100000                 True                  True  Stationary
# 9     0.100000                 True                  True  Stationary

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss

def _adf_kpss(series, regression="c"):
    s = series.dropna()
    if len(s) < 20:
        return np.nan, np.nan  # pas assez de points
    adf_p = adfuller(s, autolag="AIC")[1]
    kpss_p = kpss(s, regression=regression, nlags="auto")[1]
    return adf_p, kpss_p

def _diagnosis(adf_p, kpss_p, alpha=0.05):
    adf_stat = (adf_p < alpha) if pd.notna(adf_p) else False
    kpss_stat = (kpss_p > alpha) if pd.notna(kpss_p) else False
    if adf_stat and kpss_stat:
        return True, True, "Stationary"
    if (not adf_stat) and (not kpss_stat):
        return False, False, "Non-stationary"
    return adf_stat, kpss_stat, "Ambiguous"

def stationarize_and_test(
    df_wide: pd.DataFrame,
    transformations: dict,
    alpha: float = 0.05,
    kpss_regression: str = "c",
    add_prefix: bool = False,
):
    """
    df_wide: index=date (monthly), columns=variables
    transformations: dict {colname: 'level'|'diff'|'log_ratio'}
    add_prefix: if True, columns are renamed e.g. d_EU_rate, lr_US_fx, ...
    """
    df = df_wide.copy()

    # --- sanity check: missing keys / missing columns
    missing_in_df = [k for k in transformations.keys() if k not in df.columns]
    missing_in_dict = [c for c in df.columns if c not in transformations.keys()]

    if missing_in_df:
        print("⚠️ Keys in TRANSFORMATIONS but not in df columns:", missing_in_df)
    if missing_in_dict:
        print("⚠️ Columns in df but not in TRANSFORMATIONS (kept as level):", missing_in_dict)

    # default = level for unspecified columns
    trans = {c: transformations.get(c, "level") for c in df.columns}

    # --- tests BEFORE
    before_rows = []
    for c in df.columns:
        adf_p, kpss_p = _adf_kpss(df[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        before_rows.append({
            "variable": c,
            "transform": "level",
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    before_df = pd.DataFrame(before_rows)

    # --- apply transformations
    out = pd.DataFrame(index=df.index)

    def apply_one(s, how):
        if how == "level":
            return s
        if how == "diff":
            return s.diff()
        if how == "log_ratio":
            # safe log: only for strictly positive series
            s2 = s.replace(0, np.nan)
            return np.log(s2).diff()
        raise ValueError(f"Unknown transformation: {how}")

    rename_map = {}
    for c in df.columns:
        how = trans[c]
        s_tr = apply_one(df[c], how)
        if add_prefix:
            pref = {"level":"", "diff":"d_", "log_ratio":"lr_"}[how]
            new_name = pref + c
        else:
            new_name = c
        out[new_name] = s_tr
        rename_map[c] = new_name

    # --- tests AFTER
    after_rows = []
    for c_old in df.columns:
        c = rename_map[c_old]
        how = trans[c_old]
        adf_p, kpss_p = _adf_kpss(out[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        after_rows.append({
            "variable": c_old,
            "transform": how,
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    after_df = pd.DataFrame(after_rows)

    return out, before_df, after_df

# %%
df_macro_stationary, tests_before, tests_after = stationarize_and_test(
    df_full.drop(columns=["quarter"]),
    TRANSFORMATIONS,
    alpha=0.05,
    add_prefix=False
)

df_macro_stationary.head()
tests_after.sort_values("diagnosis").head(20)
# Out:
# ⚠️ Keys in TRANSFORMATIONS but not in df columns: ['EU_Central_bank_Intervention_rate_policy_interest_rate', 'EU_Long_term_interest_rate', 'EU_Unemployment_rate', 'EU_Effective_exchange_rate', 'EU_GDP_Growth_Rate']
# ⚠️ Columns in df but not in TRANSFORMATIONS (kept as level): ['Zt']
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
# C:\Users\werid\AppData\Local\Temp\ipykernel_28444\2235916527.py:10: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_p = kpss(s, regression=regression, nlags="auto")[1]
#                                             variable  transform    adf_pvalue  \
# 4                        US_House_prices_residential  log_ratio  2.939448e-04
# 5                                  US_Inflation_rate       diff  1.278346e-01
# 0  US_Central_bank_Intervention_rate_policy_inter...       diff  7.308402e-06
# 1                         US_Effective_exchange_rate  log_ratio  7.762195e-06
# 2                                   US_Equity_prices  log_ratio  4.961131e-14
# 3                                 US_GDP_Growth_Rate      level  4.232049e-16
# 6                         US_Long_term_interest_rate       diff  2.210028e-04
# 7                                       US_Oil_price  log_ratio  2.466993e-07
# 8                               US_Unemployment_rate       diff  3.072724e-14
# 9                                                 Zt      level  7.063579e-03
#
#    kpss_pvalue  ADF_stationary_5pct  KPSS_stationary_5pct   diagnosis
# 4     0.047688                 True                 False   Ambiguous
# 5     0.100000                False                  True   Ambiguous
# 0     0.100000                 True                  True  Stationary
# 1     0.100000                 True                  True  Stationary
# 2     0.100000                 True                  True  Stationary
# 3     0.100000                 True                  True  Stationary
# 6     0.100000                 True                  True  Stationary
# 7     0.100000                 True                  True  Stationary
# 8     0.100000                 True                  True  Stationary
# 9     0.100000                 True                  True  Stationary

# %%
df_macro_stationary
# Out:
#     US_Central_bank_Intervention_rate_policy_interest_rate  \
# 0                                                 NaN
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000000
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.083333
# 24                                           0.166667
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.083333
# 28                                           0.250000
# 29                                           0.250000
# 30                                           0.166667
# 31                                           0.083333
# 32                                           0.250000
# 33                                           0.250000
# 34                                           0.250000
# 35                                           0.250000
# 36                                           0.166667
# 37                                           0.000000
# 38                                          -0.250000
# 39                                          -0.500000
# 40                                          -0.500000
# 41                                          -1.000000
# 42                                           0.000000
# 43                                           0.000000
# 44                                           0.000000
# 45                                           0.000000
# 46                                           0.000000
# 47                                           0.000000
# 48                                           0
# 44                    0.453333      0.298676             -0.500000  0.823792
# 45                    0.276667      0.123166             -0.300000 -0.032476
# 46                   -0.270000      0.057704             -0.866666 -0.030913
# 47                    0.213333      0.085828             -0.900000  0.223604
# 48                    0.403333      0.199604             -0.333334 -0.395155
# 49                    0.990000      0.139117             -0.200000 -0.750896
# 50                    0.176667     -0.135107             -0.100000 -0.364328
# 51                    0.723333     -0.097792              0.033334 -1.696752

# %% [markdown]
# Pour les taux directeurs, la différenciation première est retenue afin d’assurer la stationnarité. Dans certains cas, les tests ADF et KPSS conduisent à des conclusions divergentes, ce qui est un résultat classique pour des séries caractérisées par de longues périodes de paliers et des changements discrets. Conformément aux pratiques usuelles, la décision repose principalement sur le test ADF et sur la cohérence économique de la transformation.

# %% [markdown]
# # Modèles Satellites
#
# ## Modèles satellites macroéconomiques (Model Averaging)
#
#
# ### Objectif
# L'objectif des modèles satellites est de relier, pour chaque secteur $s$, le facteur de risque systémique estimé à l'étape précédente, noté $Z_{s,t}$ (ou sa version standardisée $\tilde Z_{s,t}$), à un ensemble de variables macroéconomiques $X_t$.
# Cette relation permet (i) d'interpréter économiquement la dynamique du risque de crédit sectoriel et (ii) de projeter $Z_{s,t}$ sous scénarios macroéconomiques (notamment NGFS) dans les étapes ultérieures.
#
# ### Alignement temporel et transformations
# Les facteurs $Z_{s,t}$ sont initialement estimés à fréquence mensuelle. Afin d'assurer la cohérence avec les variables macroéconomiques disponibles à fréquence trimestrielle, une agrégation trimestrielle est retenue :
# $$
# Z_{s,q} = \frac{1}{3}\sum_{m \in q} Z_{s,m},
# $$
# où $q$ désigne un trimestre. Les facteurs sont ensuite standardisés par secteur :
# $$
# \tilde Z_{s,q} = \frac{Z_{s,q} - \mu_s}{\sigma_s}.
# $$
# Les variables macroéconomiques sont stationnarisées selon des transformations usuelles (différences premières pour les taux et le chômage, log-ratios pour les niveaux de prix et d'activité), conformément aux tests ADF et KPSS.
#
# ### Spécification des modèles candidats
# Pour chaque secteur $s$, on considère une famille de modèles linéaires candidats $\{M_k\}_{k=1}^K$, de la forme :
# $$
# \tilde Z_{s,q} = \alpha_{s,k} + \beta_{s,k}' X^{(k)}_{q-\ell} + u_{s,q},
# $$
# où $X^{(k)}$ représente un sous-ensemble de variables macroéconomiques (éventuellement retardées), et $\ell$ un ordre de retard retenu (par exemple $\ell \in \{0,1,2\}$).
# L'espace des modèles est construit de façon parcimonieuse afin de limiter la colinéarité et d'assurer une interprétabilité économique.
#
# ### Estimation et pondération (Model Averaging)
# Chaque modèle $M_k$ est estimé par moindres carrés ordinaires.
# Plutôt que de sélectionner un unique modèle, une combinaison pondérée des prédictions est retenue :
# $$
# \widehat{\tilde Z}_{s,q} = \sum_{k=1}^K w_k \widehat{\tilde Z}^{(k)}_{s,q},
# \qquad \sum_{k=1}^K w_k = 1,\; w_k \ge 0.
# $$
# Les poids $w_k$ peuvent être déterminés soit par un critère informationnel (AIC/BIC), soit sur la base de la performance prédictive hors-échantillon.
# Dans ce travail, une pondération basée sur la performance hors-échantillon est privilégiée, afin de maximiser la robustesse des projections.
#
# ### Validation
# La validation repose sur (i) des mesures de performance en prévision (RMSE hors-échantillon), (ii) la stabilité des résidus (autocorrélation et stationnarité), et (iii) la cohérence économique des signes estimés.
# Les poids associés aux modèles dominants sont analysés afin d'identifier les principaux déterminants macroéconomiques du risque de crédit sectoriel.

# %%
import itertools
import numpy as np
import pandas as pd
import statsmodels.api as sm

def _all_combinations(items, min_k=1, max_k=None):
    items = list(items)
    if max_k is None:
        max_k = len(items)
    for k in range(min_k, max_k + 1):
        for comb in itertools.combinations(items, k):
            yield list(comb)

def _build_design_matrix(df, x_cols, add_const=True):
    X = df[x_cols].copy()
    if add_const:
        X = sm.add_constant(X, has_constant="add")
    return X

def _fit_ols(df, y_col, x_cols, add_const=True):
    d = df[[y_col] + x_cols].dropna()
    if d.shape[0] < 30:  # garde-fou : trop peu d'observations
        return None
    
    y = d[y_col].astype(float)
    X = _build_design_matrix(d, x_cols, add_const=add_const).astype(float)
    
    try:
        model = sm.OLS(y, X).fit()
        return model
    except Exception:
        return None

def _sign_ok(beta, expected_sign, tol=1e-12):
    """
    beta: Series of coefficients (incl. const possible)
    expected_sign: dict {var: +1 or -1}
    """
    for var, sgn in expected_sign.items():
        if var not in beta.index:
            continue  # var pas dans ce modèle
        b = beta[var]
        # on tolère quasi-zéro (pour éviter de rejeter pour bruit numérique)
        if abs(b) <= tol:
            continue
        if np.sign(b) != np.sign(sgn):
            return False
    return True

# %%
def add_lags(df, cols, lags=(0,1,2), sep="_L"):
    """
    Crée des colonnes décalées.
    ex: GDP -> GDP_L0, GDP_L1, GDP_L2
    """
    out = df.copy()
    new_cols = []
    for c in cols:
        for L in lags:
            name = f"{c}{sep}{L}"
            out[name] = out[c].shift(L)
            new_cols.append(name)
    return out, new_cols

# %%
def build_admissible_model_space(
    df,
    y_col,
    x_base_cols,
    expected_sign_base,
    min_k=1,
    max_k=6,
    use_lags=False,
    lags=(0,1,2),
    lag_sep="_L",
    add_const=True,
    alpha_sign=0.05,
    require_significant=False,
    verbose=True
):
    """
    - Génère toutes les combinaisons de variables (entre min_k et max_k)
    - Estime un OLS pour chaque combinaison
    - Filtre selon signes métier (et optionnellement significance)
    
    expected_sign_base: dict {col_name: +1 or -1} pour les variables NON laggées
    Si use_lags=True, on applique le même signe à tous les lags (GDP_L1 etc.)
    """

    df_work = df.copy()

    # 1) lags
    if use_lags:
        df_work, x_cols = add_lags(df_work, x_base_cols, lags=lags, sep=lag_sep)
        # étendre les signes attendus à tous les lags
        expected_sign = {}
        for base, sgn in expected_sign_base.items():
            for L in lags:
                expected_sign[f"{base}{lag_sep}{L}"] = sgn
    else:
        x_cols = list(x_base_cols)
        expected_sign = dict(expected_sign_base)

    # 2) générer les combinaisons
    combos = list(_all_combinations(x_cols, min_k=min_k, max_k=min(max_k, len(x_cols))))
    if verbose:
        print(f"Nombre de modèles candidats: {len(combos)} (y={y_col})")

    rows = []
    admissible_models = []

    for x_list in combos:
        m = _fit_ols(df_work, y_col=y_col, x_cols=x_list, add_const=add_const)
        if m is None:
            continue
        
        beta = m.params
        
        # Filtre signe
        ok_sign = _sign_ok(beta, expected_sign)
        if not ok_sign:
            rows.append({
                "y": y_col,
                "k": len(x_list),
                "x": tuple(x_list),
                "ok_sign": False,
                "ok_sig": None,
                "aic": m.aic,
                "bic": m.bic,
                "r2_adj": m.rsquared_adj,
                "n": int(m.nobs)
            })
            continue

        # Filtre optionnel : coefficients significatifs ET au bon signe
        ok_sig = True
        if require_significant:
            pvals = m.pvalues
            for var in x_list:
                if var in pvals.index and pvals[var] > alpha_sign:
                    ok_sig = False
                    break
        
        rows.append({
            "y": y_col,
            "k": len(x_list),
            "x": tuple(x_list),
            "ok_sign": True,
            "ok_sig": ok_sig,
            "aic": m.aic,
            "bic": m.bic,
            "r2_adj": m.rsquared_adj,
            "n": int(m.nobs)
        })

        if ok_sig:
            admissible_models.append({
                "x": x_list,
                "model": m
            })

    summary = pd.DataFrame(rows).sort_values(["ok_sign", "ok_sig", "bic"], ascending=[False, False, True])

    if verbose:
        total = len(combos)
        ok_sign_count = int((summary["ok_sign"] == True).sum()) if len(summary) else 0
        ok_sig_count = int(((summary["ok_sign"] == True) & (summary["ok_sig"] == True)).sum()) if len(summary) else 0
        print(f"OK signes: {ok_sign_count}/{total}")
        if require_significant:
            print(f"OK signes + significatifs: {ok_sig_count}/{total}")

    return summary, admissible_models, df_work

# %%
EXPECTED_SIGN = {
    "EU_Central_bank_Intervention_rate_policy_interest_rate": -1,
    "EU_Long_term_interest_rate": -1,
    "EU_Unemployment_rate": -1,
    "US_Inflation_rate": -1,
    "EU_GDP_Growth_Rate": +1,
    "US_House_prices_residential": +1,
    # si tu ajoutes d'autres variables, précise le signe
}

# %%
y_col = "Zt"
x_cols = df_macro_stationary.loc[:, ~df_macro_stationary.columns.str.startswith("Z")].columns.tolist()

summary, admissible, df_used = build_admissible_model_space(
    df=df_macro_stationary,            # ton df stationnarisé aligné
    y_col=y_col,
    x_base_cols=x_cols,
    expected_sign_base=EXPECTED_SIGN,
    min_k=1,
    max_k=3,                      # évite explosion combinatoire
    use_lags=True,
    lags=(0,1,2,3,4),
    require_significant=False,    # mets True si tu veux filtrer aussi sur p-values
    verbose=True
)
# Out:
# Nombre de modèles candidats: 15225 (y=Zt)
# OK signes: 13265/15225

# %%
summary
# Out:
#         y  k                                                  x  ok_sign  \
# 3001   Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 132    Zt  2  (US_Central_bank_Intervention_rate_policy_inte...     True
# 3181   Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 2922   Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 1981   Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# ...    .. ..                                                ...      ...
# 11773  Zt  3  (US_GDP_Growth_Rate_L1, US_Inflation_rate_L0, ...    False
# 11763  Zt  3  (US_GDP_Growth_Rate_L1, US_Inflation_rate_L0, ...    False
# 11173  Zt  3  (US_GDP_Growth_Rate_L0, US_GDP_Growth_Rate_L1,...    False
# 14160  Zt  3  (US_Inflation_rate_L0, US_Long_term_interest_r...    False
# 11385  Zt  3  (US_GDP_Growth_Rate_L0, US_Inflation_rate_L0, ...    False
#
#       ok_sig         aic         bic    r2_adj   n
# 3001    True   77.227858   84.795139  0.569955  49
# 132     True   79.262613   84.876216  0.518298  48
# 3181    True   77.808313   85.375595  0.564830  49
# 2922    True   78.020143   85.504947  0.539531  48
# 1981    True   78.047455   85.532259  0.539269  48
# ...      ...         ...         ...       ...  ..
# 11773   None  127.943726  135.671029 -0.055527  51
# 11763   None  128.116256  135.843558 -0.059103  51
# 11173   None  128.128152  135.855455 -0.059351  51
# 14160   None  128.131776  135.859078 -0.059426  51
# 11385   None  128.299451  136.026754 -0.062915  51
#
# [15225 rows x 9 columns]

# %%
x_cols
# Out:
# ['US_Central_bank_Intervention_rate_policy_interest_rate',
#  'US_Effective_exchange_rate',
#  'US_Equity_prices',
#  'US_GDP_Growth_Rate',
#  'US_House_prices_residential',
#  'US_Inflation_rate',
#  'US_Long_term_interest_rate',
#  'US_Oil_price',
#  'US_Unemployment_rate']

# %%
summary=summary.sort_values(by="r2_adj",ascending=False).head(20)

# %%
top10 = summary[(summary["ok_sign"] == True) & (summary["ok_sig"] != False)].head(10)
top10
# Out:
#        y  k                                                  x  ok_sign  \
# 3001  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 3181  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 2976  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 3156  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 2922  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 1981  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 2890  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 3651  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 2887  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
# 3622  Zt  3  (US_Central_bank_Intervention_rate_policy_inte...     True
#
#      ok_sig        aic        bic    r2_adj   n
# 3001   True  77.227858  84.795139  0.569955  49
# 3181   True  77.808313  85.375595  0.564830  49
# 2976   True  78.071300  85.638581  0.562488  49
# 3156   True  78.678326  86.245608  0.557035  49
# 2922   True  78.020143  85.504947  0.539531  48
# 1981   True  78.047455  85.532259  0.539269  48
# 2890   True  78.449776  85.934580  0.535391  48
# 3651   True  81.051203  88.618485  0.535056  49
# 2887   True  78.648660  86.133464  0.533462  48
# 3622   True  78.796654  86.281459  0.532021  48

# %%
import numpy as np
import pandas as pd

import statsmodels.api as sm
from statsmodels.stats.diagnostic import acorr_ljungbox, het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from statsmodels.tsa.stattools import adfuller

from scipy.stats import shapiro, jarque_bera
from itertools import combinations
from scipy.optimize import minimize

# %%
import unicodedata
import re

def _norm_name(s: str) -> str:
    s = str(s)
    s = unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("ascii")  # enlève accents
    s = s.upper()
    s = re.sub(r"[^A-Z0-9_]+", "_", s)
    s = re.sub(r"_+", "_", s).strip("_")
    return s

def find_col(df: pd.DataFrame, wanted: str) -> str:
    w = _norm_name(wanted)
    mapping = { _norm_name(c): c for c in df.columns }
    if w in mapping:
        return mapping[w]
    # fallback : contains
    for k, v in mapping.items():
        if w in k or k in w:
            return v
    raise KeyError(f"Impossible de trouver une colonne proche de: {wanted}. Exemples colonnes Z: {df.filter(like='Z_').columns[:5].tolist()}")

# %%
df_macro_stationary
# Out:
#     US_Central_bank_Intervention_rate_policy_interest_rate  \
# 0                                                 NaN
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000000
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.083333
# 24                                           0.166667
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0
# 33                    0.160000      0.108955             -0.100000 -0.471350
# 34                    0.006667      0.015780             -0.166666 -0.962522
# 35                    0.106667     -0.107597              0.066666 -1.927952
# 36                   -0.380000     -0.069126              0.033334 -1.788685
# 37                   -0.320000      0.069679             -0.233334 -1.663545
# 38                   -0.536667     -0.095628             -0.033333 -1.105886
# 39                   -0.003333      0.006924              0.000000  0.092922
# 40                   -0.416667     -0.200723              0.233333  0.734780
# 41                   -0.690000     -0.427457              9.166667  1.435027
# 42                   -0.036667      0.263385             -4.200000  1.531983
# 43                    0.213333      0.043034             -2.066667  1.339270
# 44                    0.453333      0.298676             -0.500000  0.823792
# 45                    0.276667      0.123166             -0.300000 -0.032476
# 46                   -0.270000      0.057704             -0.866666 -0.030913
# 47                    0.213333      0.085828             -0.900000  0.223604
# 48                    0.403333      0.199604             -0.333334 -0.395155
# 49                    0.990000      0.139117             -0.200000 -0.750896
# 50                    0.176667     -0.135107             -0.100000 -0.364328
# 51                    0.723333     -0.097792              0.033334 -1.696752

# %%
y_col = find_col(df_macro_stationary, "Z_")

# %%
def make_lagged_features(df: pd.DataFrame, cols, lags=(0,1,2,3,4)):
    out = {}
    for c in cols:
        for L in lags:
            name = f"{c}_L{L}"
            out[name] = df[c] if L == 0 else df[c].shift(L)
    return pd.DataFrame(out, index=df.index)

# %%
def expand_expected_sign(expected_sign_base: dict, lags=(0,1,2,3,4)):
    exp = {}
    for var, sgn in expected_sign_base.items():
        for L in lags:
            exp[f"{var}_L{L}"] = sgn
    return exp

def sign_constraints_ok(params: pd.Series, expected_sign: dict, tol=1e-12):
    for var, sgn in expected_sign.items():
        if var in params.index:
            b = params[var]
            if abs(b) <= tol:
                continue
            if np.sign(b) != np.sign(sgn):
                return False
    return True

# %%
def fit_ols_hac(df, y_col, x_cols, hac_lags=4, add_const=True, min_obs=40):
    d = df[[y_col] + x_cols].dropna().copy()
    if d.shape[0] < min_obs:
        return None

    y = d[y_col].astype(float)
    X = d[x_cols].astype(float)
    if add_const:
        X = sm.add_constant(X, has_constant="add")

    try:
        ols = sm.OLS(y, X).fit()
        hac = ols.get_robustcov_results(cov_type="HAC", maxlags=hac_lags)
        return {"ols": ols, "hac": hac, "data": d, "X": X, "y": y}
    except Exception:
        return None

# %%
def residual_diagnostics(fit_dict, lb_lags=12, alpha=0.05):
    ols = fit_dict["ols"]
    X = fit_dict["X"]
    resid = ols.resid

    lb = acorr_ljungbox(resid, lags=[lb_lags], return_df=True)
    lb_p = float(lb["lb_pvalue"].iloc[0])

    bp_stat, bp_p, _, _ = het_breuschpagan(resid, X)

    sh_p = shapiro(resid)[1] if len(resid) <= 5000 else np.nan
    jb_p = jarque_bera(resid)[1]

    adf_p = adfuller(resid.dropna(), autolag="AIC")[1] if resid.notna().sum() > 20 else np.nan
    dw = durbin_watson(resid)

    return {
        "n": int(len(resid)),
        "lb_pvalue": lb_p,
        "bp_pvalue": float(bp_p),
        "shapiro_pvalue": float(sh_p) if not np.isnan(sh_p) else np.nan,
        "jb_pvalue": float(jb_p),
        "adf_resid_pvalue": float(adf_p) if not np.isnan(adf_p) else np.nan,
        "dw": float(dw),
        "LB_ok_5pct": (lb_p > alpha),
        "BP_ok_5pct": (bp_p > alpha),
    }

# %%
def build_admissible_model_space(
    df: pd.DataFrame,
    y_col: str,
    x_base_cols: list,
    expected_sign_base: dict,
    min_k=1,
    max_k=3,
    use_lags=True,
    lags=(0,1,2,3,4),
    verbose=True
):
    # features X (laggées ou non)
    if use_lags:
        Xfeat = make_lagged_features(df, x_base_cols, lags=lags)
        expected_sign = expand_expected_sign(expected_sign_base, lags=lags)
    else:
        Xfeat = df[x_base_cols].copy()
        expected_sign = expected_sign_base.copy()

    df_used = pd.concat([df[[y_col]], Xfeat], axis=1)

    all_models = []
    for k in range(min_k, max_k+1):
        for comb in combinations(Xfeat.columns.tolist(), k):
            all_models.append(list(comb))

    if verbose:
        print(f"Nb variables candidates: {Xfeat.shape[1]}")
        print(f"Nb modèles (combinaisons {min_k}..{max_k}): {len(all_models)}")

    rows = []
    admissible = []
    for i, x_cols in enumerate(all_models):
        fit = fit_ols_hac(df_used, y_col, x_cols, hac_lags=max(lags), min_obs=40)
        if fit is None:
            continue

        ok_sign = sign_constraints_ok(fit["ols"].params, expected_sign)
        rows.append({
            "model_id": i,
            "k": len(x_cols),
            "x_cols": x_cols,
            "ok_sign": ok_sign,
            "aic": fit["ols"].aic,
            "bic": fit["ols"].bic,
            "r2_adj": fit["ols"].rsquared_adj
        })
        if ok_sign:
            admissible.append({"name": f"m{i}", "x": x_cols})

    summary = pd.DataFrame(rows).sort_values(["ok_sign","bic"], ascending=[False, True])
    if verbose and not summary.empty:
        print("OK_sign:", int(summary["ok_sign"].sum()), "/", summary.shape[0])

    return summary, admissible, df_used

# %%
def hac_significance_ok(hac_res, x_cols, alpha=0.05, min_sig=1):
    pvals = pd.Series(hac_res.pvalues, index=hac_res.model.exog_names)
    vars_in = [v for v in x_cols if v in pvals.index]
    if not vars_in:
        return False
    return int((pvals[vars_in] < alpha).sum()) >= min_sig

def build_candidate_pool_and_filter(
    df, y_col, candidate_models, expected_sign,
    hac_lags=4, lb_lags=12, alpha=0.05,
    require_sig=False, sig_alpha=0.05, min_sig=1,
    enforce_bp=False, enforce_lb=True
):
    kept = []
    summary_rows = []

    for m in candidate_models:
        x_cols = m["x"]
        fit = fit_ols_hac(df, y_col, x_cols, hac_lags=hac_lags)
        if fit is None:
            continue

        ok_sign = sign_constraints_ok(fit["ols"].params, expected_sign)
        diag = residual_diagnostics(fit, lb_lags=lb_lags, alpha=alpha)

        ok_sig = True
        if require_sig:
            ok_sig = hac_significance_ok(fit["hac"], x_cols, alpha=sig_alpha, min_sig=min_sig)

        ok_lb = diag["LB_ok_5pct"] if enforce_lb else True
        ok_bp = diag["BP_ok_5pct"] if enforce_bp else True

        ok = ok_sign and ok_lb and ok_bp and ok_sig

        summary_rows.append({
            "model": m.get("name", str(tuple(x_cols))),
            "k": len(x_cols),
            "ok": ok,
            "ok_sign": ok_sign,
            "ok_lb": ok_lb,
            "ok_bp": ok_bp,
            "ok_sig": ok_sig,
            "aic": fit["ols"].aic,
            "bic": fit["ols"].bic,
            "r2_adj": fit["ols"].rsquared_adj,
            **diag
        })

        if ok:
            kept.append(m)

    summary = pd.DataFrame(summary_rows).sort_values(["ok","bic"], ascending=[False, True])
    return kept, summary

# %%
def solve_simplex_weights_slsqp(Y, y):
    """
    Min ||y - Yw||^2 s.c w>=0, sum w = 1
    """
    T, M = Y.shape
    w0 = np.ones(M) / M

    cons = (
        {"type": "eq", "fun": lambda w: np.sum(w) - 1.0},
    )
    bounds = [(0.0, 1.0)] * M

    def obj(w):
        r = y - Y @ w
        return float(r.T @ r)

    res = minimize(obj, w0, method="SLSQP", bounds=bounds, constraints=cons)
    if not res.success:
        return None
    return res.x

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

def fixed_model_predictions(df, y_col, x_cols, hac_lags=4, add_const=True,
                            train_slice=None, pred_slice=None):
    """
    Estime le modèle UNE SEULE FOIS (sur train_slice), puis prédit sur pred_slice.
    - train_slice: ex "2011-04-01":"2020-10-01" (ou None => tout df utilisable)
    - pred_slice : ex "2011-04-01":"2024-01-01" (ou None => mêmes dates que df utilisable)
    """
    # Sous-ensemble pour l'estimation
    d_all = df[[y_col] + x_cols].copy()

    if train_slice is not None:
        d_train = d_all.loc[train_slice].dropna()
    else:
        d_train = d_all.dropna()

    fit = fit_ols_hac(d_train, y_col, x_cols, hac_lags=hac_lags, add_const=add_const)
    if fit is None:
        return pd.Series(index=df.index, dtype=float)

    ols = fit["ols"]

    # Sous-ensemble pour la prédiction
    if pred_slice is not None:
        d_pred = d_all.loc[pred_slice].dropna(subset=x_cols)  # on peut prédire même si y est NA
    else:
        d_pred = d_all.dropna(subset=x_cols)

    X_pred = d_pred[x_cols].astype(float)
    if add_const:
        X_pred = sm.add_constant(X_pred, has_constant="add")

    yhat = pd.Series(index=df.index, dtype=float)
    yhat.loc[d_pred.index] = ols.predict(X_pred).values
    return yhat


def stacking_and_jma_fixed(df, y_col, kept_models, hac_lags=4, add_const=True,
                           train_slice=None, pred_slice=None,
                           weight_fit_slice=None):
    """
    - Prédictions de chaque modèle: fit 1 fois (train_slice), prédire sur pred_slice
    - Poids stacking/JMA: estimés sur weight_fit_slice (sinon: intersection où y et toutes preds existent)
    """
    preds = {}
    for i, m in enumerate(kept_models):
        name = m.get("name", f"m{i}")
        preds[name] = fixed_model_predictions(
            df=df,
            y_col=y_col,
            x_cols=m["x"],
            hac_lags=hac_lags,
            add_const=add_const,
            train_slice=train_slice,
            pred_slice=pred_slice
        )

    P = pd.DataFrame(preds)

    # Data pour estimer les poids: il faut y et toutes les preds non-NA
    if weight_fit_slice is not None:
        d_w = pd.concat([df[[y_col]].loc[weight_fit_slice], P.loc[weight_fit_slice]], axis=1).dropna()
    else:
        d_w = pd.concat([df[[y_col]], P], axis=1).dropna()

    y = d_w[y_col].values
    Y = d_w[P.columns].values

    w = solve_simplex_weights_slsqp(Y, y)
    if w is None:
        raise RuntimeError("Solver SLSQP a échoué pour les poids.")

    weights = pd.Series(w, index=P.columns, name="w_stacking")

    # Série finale des prédictions moyennées (sur les dates où on a des prédictions pour tous les modèles)
    d_pred = P.dropna()  # intersection des dates prédictibles
    yhat = pd.Series(d_pred.values @ w, index=d_pred.index, name="yhat_stacked")

    return {
        "P": P,
        "weights_stacking": weights,
        "weights_jma": weights.rename("w_jma"),
        "oos_frame_weights": d_w,   # frame utilisée pour apprendre les poids
        "yhat_stacked": yhat
    }

# %% [markdown]
# APPLICATION

# %%
y_col = find_col(df_macro_stationary, "Zt")
print("y_col retenu =", y_col)
# Out:
# y_col retenu = Zt

# %%
x_cols = df_macro_stationary.loc[:, ~df_macro_stationary.columns.str.startswith("Z")].columns.tolist()

# %%
x_cols
# Out:
# ['US_Central_bank_Intervention_rate_policy_interest_rate',
#  'US_Effective_exchange_rate',
#  'US_Equity_prices',
#  'US_GDP_Growth_Rate',
#  'US_House_prices_residential',
#  'US_Inflation_rate',
#  'US_Long_term_interest_rate',
#  'US_Oil_price',
#  'US_Unemployment_rate']

# %%
EXPECTED_SIGN = {
    "US_Central_bank_Intervention_rate_policy_interest_rate": -1,
    "US_Long_term_interest_rate": -1,
    "US_Unemployment_rate": -1,
    "US_Inflation_rate": -1,             
    "US_House_prices_residential": +1,
    "US_GDP_Growth_Rate": +1,
}

# %%
summary, admissible, df_used = build_admissible_model_space(
    df=df_macro_stationary,
    y_col=y_col,
    x_base_cols=x_cols,
    expected_sign_base=EXPECTED_SIGN,
    min_k=1,
    max_k=3,
    use_lags=True,
    lags=(0,1,2,3,4),
    verbose=True
)

summary.head(10)
print("Nb modèles admissibles (signe OK):", len(admissible))
# Out:
# Nb variables candidates: 45
# Nb modèles (combinaisons 1..3): 15225
# OK_sign: 6281 / 15225
# Nb modèles admissibles (signe OK): 6281

# %%
summary
# Out:
#        model_id  k                                             x_cols  \
# 3001       3001  3  [US_Central_bank_Intervention_rate_policy_inte...
# 132         132  2  [US_Central_bank_Intervention_rate_policy_inte...
# 3181       3181  3  [US_Central_bank_Intervention_rate_policy_inte...
# 2922       2922  3  [US_Central_bank_Intervention_rate_policy_inte...
# 1981       1981  3  [US_Central_bank_Intervention_rate_policy_inte...
# ...         ... ..                                                ...
# 11178     11178  3  [US_GDP_Growth_Rate_L0, US_GDP_Growth_Rate_L1,...
# 11763     11763  3  [US_GDP_Growth_Rate_L1, US_Inflation_rate_L0, ...
# 11173     11173  3  [US_GDP_Growth_Rate_L0, US_GDP_Growth_Rate_L1,...
# 14160     14160  3  [US_Inflation_rate_L0, US_Long_term_interest_r...
# 11385     11385  3  [US_GDP_Growth_Rate_L0, US_Inflation_rate_L0, ...
#
#        ok_sign         aic         bic    r2_adj
# 3001      True   77.227858   84.795139  0.569955
# 132       True   79.262613   84.876216  0.518298
# 3181      True   77.808313   85.375595  0.564830
# 2922      True   78.020143   85.504947  0.539531
# 1981      True   78.047455   85.532259  0.539269
# ...        ...         ...         ...       ...
# 11178    False  128.113226  135.840528 -0.059041
# 11763    False  128.116256  135.843558 -0.059103
# 11173    False  128.128152  135.855455 -0.059351
# 14160    False  128.131776  135.859078 -0.059426
# 11385    False  128.299451  136.026754 -0.062915
#
# [15225 rows x 7 columns]

# %%
admissible
# Out:
# [{'name': 'm0',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0']},
#  {'name': 'm1',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1']},
#  {'name': 'm2',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2']},
#  {'name': 'm3',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3']},
#  {'name': 'm4',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4']},
#  {'name': 'm5', 'x': ['US_Effective_exchange_rate_L0']},
#  {'name': 'm6', 'x': ['US_Effective_exchange_rate_L1']},
#  {'name': 'm7', 'x': ['US_Effective_exchange_rate_L2']},
#  {'name': 'm8', 'x': ['US_Effective_exchange_rate_L3']},
#  {'name': 'm9', 'x': ['US_Effective_exchange_rate_L4']},
#  {'name': 'm10', 'x': ['US_Equity_prices_L0']},
#  {'name': 'm11', 'x': ['US_Equity_prices_L1']},
#  {'name': 'm12', 'x': ['US_Equity_prices_L2']},
#  {'name': 'm13', 'x': ['US_Equity_prices_L3']},
#  {'name': 'm14', 'x': ['US_Equity_prices_L4']},
#  {'name': 'm15', 'x': ['US_GDP_Growth_Rate_L0']},
#  {'name': 'm20', 'x': ['US_House_prices_residential_L0']},
#  {'name': 'm21', 'x': ['US_House_prices_residential_L1']},
#  {'name': 'm22', 'x': ['US_House_prices_residential_L2']},
#  {'name': 'm23', 'x': ['US_House_prices_residential_L3']},
#  {'name': 'm25', 'x': ['US_Inflation_rate_L0']},
#  {'name': 'm26', 'x': ['US_Inflation_rate_L1']},
#  {'name': 'm27', 'x': ['US_Inflation_rate_L2']},
#  {'name': 'm28', 'x': ['US_Inflation_rate_L3']},
#  {'name': 'm29', 'x': ['US_Inflation_rate_L4']},
#  {'name': 'm30', 'x': ['US_Long_term_interest_rate_L0']},
#  {'name': 'm31', 'x': ['US_Long_term_interest_rate_L1']},
#  {'name': 'm32', 'x': ['US_Long_term_interest_rate_L2']},
#  {'name': 'm33', 'x': ['US_Long_term_interest_rate_L3']},
#  {'name': 'm34', 'x': ['US_Long_term_interest_rate_L4']},
#  {'name': 'm35', 'x': ['US_Oil_price_L0']},
#  {'name': 'm36', 'x': ['US_Oil_price_L1']},
#  {'name': 'm37', 'x': ['US_Oil_price_L2']},
#  {'name': 'm38', 'x': ['US_Oil_price_L3']},
#  {'name': 'm39', 'x': ['US_Oil_price_L4']},
#  {'name': 'm46',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L2']},
#  {'name': 'm47',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L3']},
#  {'name': 'm48',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L4']},
#  {'name': 'm49',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Effective_exchange_rate_L0']},
#  {'name': 'm50',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Effective_exchange_rate_L1']},
#  {'name': 'm51',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Effective_exchange_rate_L2']},
#  {'name': 'm52',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Effective_exchange_rate_L3']},
#  {'name': 'm53',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Effective_exchange_rate_L4']},
#  {'name': 'm54',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L0']},
#  {'name': 'm55',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L1']},
#  {'name': 'm56',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L2']},
#  {'name': 'm57',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L3']},
#  {'name': 'm58',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4']},
#  {'name': 'm59',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0']},
#  {'name': 'm64',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0']},
#  {'name': 'm65',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1']},
#  {'name': 'm66',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2']},
#  {'name': 'm67',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3']},
#  {'name': 'm68',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4']},
#  {'name': 'm70',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Inflation_rate_L1']},
#  {'name': 'm71',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Inflation_rate_L2']},
#  {'name': 'm72',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Inflation_rate_L3']},
#  {'name': 'm73',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Inflation_rate_L4']},
#  {'name': 'm76',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm77',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm78',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm79',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Oil_price_L0']},
#  {'name': 'm80',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Oil_price_L1']},
#  {'name': 'm81',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Oil_price_L2']},
#  {'name': 'm82',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Oil_price_L3']},
#  {'name': 'm83',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Oil_price_L4']},
#  {'name': 'm84',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm89',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L2']},
#  {'name': 'm90',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L3']},
#  {'name': 'm91',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L4']},
#  {'name': 'm92',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Effective_exchange_rate_L0']},
#  {'name': 'm93',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Effective_exchange_rate_L1']},
#  {'name': 'm94',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Effective_exchange_rate_L2']},
#  {'name': 'm95',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Effective_exchange_rate_L3']},
#  {'name': 'm96',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Effective_exchange_rate_L4']},
#  {'name': 'm97',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Equity_prices_L0']},
#  {'name': 'm98',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Equity_prices_L1']},
#  {'name': 'm99',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Equity_prices_L2']},
#  {'name': 'm100',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Equity_prices_L3']},
#  {'name': 'm101',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Equity_prices_L4']},
#  {'name': 'm103',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_GDP_Growth_Rate_L1']},
#  {'name': 'm107',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_House_prices_residential_L0']},
#  {'name': 'm108',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_House_prices_residential_L1']},
#  {'name': 'm109',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_House_prices_residential_L2']},
#  {'name': 'm110',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_House_prices_residential_L3']},
#  {'name': 'm111',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_House_prices_residential_L4']},
#  {'name': 'm112',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Inflation_rate_L0']},
#  {'name': 'm113',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Inflation_rate_L1']},
#  {'name': 'm114',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Inflation_rate_L2']},
#  {'name': 'm115',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Inflation_rate_L3']},
#  {'name': 'm116',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Inflation_rate_L4']},
#  {'name': 'm119',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm120',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm121',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm122',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Oil_price_L0']},
#  {'name': 'm123',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Oil_price_L1']},
#  {'name': 'm124',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Oil_price_L2']},
#  {'name': 'm125',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Oil_price_L3']},
#  {'name': 'm126',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Oil_price_L4']},
#  {'name': 'm128',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Unemployment_rate_L1']},
#  {'name': 'm131',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L1',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm132',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L3']},
#  {'name': 'm133',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L4']},
#  {'name': 'm134',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Effective_exchange_rate_L0']},
#  {'name': 'm135',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Effective_exchange_rate_L1']},
#  {'name': 'm136',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Effective_exchange_rate_L2']},
#  {'name': 'm137',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Effective_exchange_rate_L3']},
#  {'name': 'm138',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Effective_exchange_rate_L4']},
#  {'name': 'm139',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Equity_prices_L0']},
#  {'name': 'm140',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Equity_prices_L1']},
#  {'name': 'm141',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Equity_prices_L2']},
#  {'name': 'm142',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Equity_prices_L3']},
#  {'name': 'm143',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Equity_prices_L4']},
#  {'name': 'm144',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_GDP_Growth_Rate_L0']},
#  {'name': 'm146',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_GDP_Growth_Rate_L2']},
#  {'name': 'm149',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_House_prices_residential_L0']},
#  {'name': 'm150',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_House_prices_residential_L1']},
#  {'name': 'm151',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_House_prices_residential_L2']},
#  {'name': 'm152',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_House_prices_residential_L3']},
#  {'name': 'm154',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Inflation_rate_L0']},
#  {'name': 'm155',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Inflation_rate_L1']},
#  {'name': 'm157',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Inflation_rate_L3']},
#  {'name': 'm158',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Inflation_rate_L4']},
#  {'name': 'm160',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Long_term_interest_rate_L1']},
#  {'name': 'm161',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm162',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm163',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm164',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Oil_price_L0']},
#  {'name': 'm165',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Oil_price_L1']},
#  {'name': 'm166',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Oil_price_L2']},
#  {'name': 'm167',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Oil_price_L3']},
#  {'name': 'm168',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Oil_price_L4']},
#  {'name': 'm171',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L2',
#    'US_Unemployment_rate_L2']},
#  {'name': 'm174',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Central_bank_Intervention_rate_policy_interest_rate_L4']},
#  {'name': 'm175',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Effective_exchange_rate_L0']},
#  {'name': 'm176',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Effective_exchange_rate_L1']},
#  {'name': 'm177',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Effective_exchange_rate_L2']},
#  {'name': 'm178',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Effective_exchange_rate_L3']},
#  {'name': 'm179',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Effective_exchange_rate_L4']},
#  {'name': 'm180',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Equity_prices_L0']},
#  {'name': 'm181',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Equity_prices_L1']},
#  {'name': 'm182',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Equity_prices_L2']},
#  {'name': 'm183',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Equity_prices_L3']},
#  {'name': 'm184',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Equity_prices_L4']},
#  {'name': 'm188',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_GDP_Growth_Rate_L3']},
#  {'name': 'm190',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_House_prices_residential_L0']},
#  {'name': 'm191',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_House_prices_residential_L1']},
#  {'name': 'm192',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_House_prices_residential_L2']},
#  {'name': 'm196',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Inflation_rate_L1']},
#  {'name': 'm197',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Inflation_rate_L2']},
#  {'name': 'm198',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Inflation_rate_L3']},
#  {'name': 'm199',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Inflation_rate_L4']},
#  {'name': 'm200',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Long_term_interest_rate_L0']},
#  {'name': 'm201',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Long_term_interest_rate_L1']},
#  {'name': 'm202',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm203',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm204',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm205',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Oil_price_L0']},
#  {'name': 'm206',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Oil_price_L1']},
#  {'name': 'm207',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Oil_price_L2']},
#  {'name': 'm208',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Oil_price_L3']},
#  {'name': 'm209',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Oil_price_L4']},
#  {'name': 'm213',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L3',
#    'US_Unemployment_rate_L3']},
#  {'name': 'm215',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Effective_exchange_rate_L0']},
#  {'name': 'm216',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Effective_exchange_rate_L1']},
#  {'name': 'm217',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Effective_exchange_rate_L2']},
#  {'name': 'm218',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Effective_exchange_rate_L3']},
#  {'name': 'm219',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Effective_exchange_rate_L4']},
#  {'name': 'm220',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Equity_prices_L0']},
#  {'name': 'm221',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Equity_prices_L1']},
#  {'name': 'm222',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Equity_prices_L2']},
#  {'name': 'm223',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Equity_prices_L3']},
#  {'name': 'm224',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Equity_prices_L4']},
#  {'name': 'm229',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_GDP_Growth_Rate_L4']},
#  {'name': 'm230',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_House_prices_residential_L0']},
#  {'name': 'm231',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_House_prices_residential_L1']},
#  {'name': 'm232',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_House_prices_residential_L2']},
#  {'name': 'm235',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Inflation_rate_L0']},
#  {'name': 'm236',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Inflation_rate_L1']},
#  {'name': 'm237',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Inflation_rate_L2']},
#  {'name': 'm238',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Inflation_rate_L3']},
#  {'name': 'm239',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Inflation_rate_L4']},
#  {'name': 'm240',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Long_term_interest_rate_L0']},
#  {'name': 'm241',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Long_term_interest_rate_L1']},
#  {'name': 'm242',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm243',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm244',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm245',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Oil_price_L0']},
#  {'name': 'm246',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Oil_price_L1']},
#  {'name': 'm247',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Oil_price_L2']},
#  {'name': 'm248',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Oil_price_L3']},
#  {'name': 'm249',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Oil_price_L4']},
#  {'name': 'm254',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L4',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm255',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Effective_exchange_rate_L1']},
#  {'name': 'm256',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Effective_exchange_rate_L2']},
#  {'name': 'm257',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Effective_exchange_rate_L3']},
#  {'name': 'm258',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Effective_exchange_rate_L4']},
#  {'name': 'm259',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Equity_prices_L0']},
#  {'name': 'm260',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Equity_prices_L1']},
#  {'name': 'm261',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Equity_prices_L2']},
#  {'name': 'm262',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Equity_prices_L3']},
#  {'name': 'm263',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Equity_prices_L4']},
#  {'name': 'm269',
#   'x': ['US_Effective_exchange_rate_L0', 'US_House_prices_residential_L0']},
#  {'name': 'm270',
#   'x': ['US_Effective_exchange_rate_L0', 'US_House_prices_residential_L1']},
#  {'name': 'm271',
#   'x': ['US_Effective_exchange_rate_L0', 'US_House_prices_residential_L2']},
#  {'name': 'm272',
#   'x': ['US_Effective_exchange_rate_L0', 'US_House_prices_residential_L3']},
#  {'name': 'm274',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Inflation_rate_L0']},
#  {'name': 'm275',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Inflation_rate_L1']},
#  {'name': 'm276',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Inflation_rate_L2']},
#  {'name': 'm277',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Inflation_rate_L3']},
#  {'name': 'm278',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Inflation_rate_L4']},
#  {'name': 'm279',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm280',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm281',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm282',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm283',
#   'x': ['US_Effective_exchange_rate_L0', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm284', 'x': ['US_Effective_exchange_rate_L0', 'US_Oil_price_L0']},
#  {'name': 'm285', 'x': ['US_Effective_exchange_rate_L0', 'US_Oil_price_L1']},
#  {'name': 'm286', 'x': ['US_Effective_exchange_rate_L0', 'US_Oil_price_L2']},
#  {'name': 'm287', 'x': ['US_Effective_exchange_rate_L0', 'US_Oil_price_L3']},
#  {'name': 'm288', 'x': ['US_Effective_exchange_rate_L0', 'US_Oil_price_L4']},
#  {'name': 'm294',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Effective_exchange_rate_L2']},
#  {'name': 'm295',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Effective_exchange_rate_L3']},
#  {'name': 'm296',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Effective_exchange_rate_L4']},
#  {'name': 'm297',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Equity_prices_L0']},
#  {'name': 'm298',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Equity_prices_L1']},
#  {'name': 'm299',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Equity_prices_L2']},
#  {'name': 'm300',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Equity_prices_L3']},
#  {'name': 'm301',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Equity_prices_L4']},
#  {'name': 'm302',
#   'x': ['US_Effective_exchange_rate_L1', 'US_GDP_Growth_Rate_L0']},
#  {'name': 'm307',
#   'x': ['US_Effective_exchange_rate_L1', 'US_House_prices_residential_L0']},
#  {'name': 'm308',
#   'x': ['US_Effective_exchange_rate_L1', 'US_House_prices_residential_L1']},
#  {'name': 'm309',
#   'x': ['US_Effective_exchange_rate_L1', 'US_House_prices_residential_L2']},
#  {'name': 'm310',
#   'x': ['US_Effective_exchange_rate_L1', 'US_House_prices_residential_L3']},
#  {'name': 'm312',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Inflation_rate_L0']},
#  {'name': 'm313',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Inflation_rate_L1']},
#  {'name': 'm314',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Inflation_rate_L2']},
#  {'name': 'm315',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Inflation_rate_L3']},
#  {'name': 'm316',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Inflation_rate_L4']},
#  {'name': 'm317',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm318',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm319',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm320',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm321',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm322', 'x': ['US_Effective_exchange_rate_L1', 'US_Oil_price_L0']},
#  {'name': 'm323', 'x': ['US_Effective_exchange_rate_L1', 'US_Oil_price_L1']},
#  {'name': 'm324', 'x': ['US_Effective_exchange_rate_L1', 'US_Oil_price_L2']},
#  {'name': 'm325', 'x': ['US_Effective_exchange_rate_L1', 'US_Oil_price_L3']},
#  {'name': 'm326', 'x': ['US_Effective_exchange_rate_L1', 'US_Oil_price_L4']},
#  {'name': 'm331',
#   'x': ['US_Effective_exchange_rate_L1', 'US_Unemployment_rate_L4']},
#  {'name': 'm332',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Effective_exchange_rate_L3']},
#  {'name': 'm333',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Effective_exchange_rate_L4']},
#  {'name': 'm334',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Equity_prices_L0']},
#  {'name': 'm335',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Equity_prices_L1']},
#  {'name': 'm336',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Equity_prices_L2']},
#  {'name': 'm337',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Equity_prices_L3']},
#  {'name': 'm338',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Equity_prices_L4']},
#  {'name': 'm344',
#   'x': ['US_Effective_exchange_rate_L2', 'US_House_prices_residential_L0']},
#  {'name': 'm345',
#   'x': ['US_Effective_exchange_rate_L2', 'US_House_prices_residential_L1']},
#  {'name': 'm346',
#   'x': ['US_Effective_exchange_rate_L2', 'US_House_prices_residential_L2']},
#  {'name': 'm347',
#   'x': ['US_Effective_exchange_rate_L2', 'US_House_prices_residential_L3']},
#  {'name': 'm350',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Inflation_rate_L1']},
#  {'name': 'm351',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Inflation_rate_L2']},
#  {'name': 'm352',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Inflation_rate_L3']},
#  {'name': 'm353',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Inflation_rate_L4']},
#  {'name': 'm355',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm356',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm357',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm358',
#   'x': ['US_Effective_exchange_rate_L2', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm359', 'x': ['US_Effective_exchange_rate_L2', 'US_Oil_price_L0']},
#  {'name': 'm360', 'x': ['US_Effective_exchange_rate_L2', 'US_Oil_price_L1']},
#  {'name': 'm361', 'x': ['US_Effective_exchange_rate_L2', 'US_Oil_price_L2']},
#  {'name': 'm362', 'x': ['US_Effective_exchange_rate_L2', 'US_Oil_price_L3']},
#  {'name': 'm363', 'x': ['US_Effective_exchange_rate_L2', 'US_Oil_price_L4']},
#  {'name': 'm369',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Effective_exchange_rate_L4']},
#  {'name': 'm370',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Equity_prices_L0']},
#  {'name': 'm371',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Equity_prices_L1']},
#  {'name': 'm372',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Equity_prices_L2']},
#  {'name': 'm373',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Equity_prices_L3']},
#  {'name': 'm374',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Equity_prices_L4']},
#  {'name': 'm380',
#   'x': ['US_Effective_exchange_rate_L3', 'US_House_prices_residential_L0']},
#  {'name': 'm381',
#   'x': ['US_Effective_exchange_rate_L3', 'US_House_prices_residential_L1']},
#  {'name': 'm382',
#   'x': ['US_Effective_exchange_rate_L3', 'US_House_prices_residential_L2']},
#  {'name': 'm383',
#   'x': ['US_Effective_exchange_rate_L3', 'US_House_prices_residential_L3']},
#  {'name': 'm386',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Inflation_rate_L1']},
#  {'name': 'm387',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Inflation_rate_L2']},
#  {'name': 'm388',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Inflation_rate_L3']},
#  {'name': 'm389',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Inflation_rate_L4']},
#  {'name': 'm391',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm392',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm393',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm394',
#   'x': ['US_Effective_exchange_rate_L3', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm395', 'x': ['US_Effective_exchange_rate_L3', 'US_Oil_price_L0']},
#  {'name': 'm396', 'x': ['US_Effective_exchange_rate_L3', 'US_Oil_price_L1']},
#  {'name': 'm397', 'x': ['US_Effective_exchange_rate_L3', 'US_Oil_price_L2']},
#  {'name': 'm398', 'x': ['US_Effective_exchange_rate_L3', 'US_Oil_price_L3']},
#  {'name': 'm399', 'x': ['US_Effective_exchange_rate_L3', 'US_Oil_price_L4']},
#  {'name': 'm405',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Equity_prices_L0']},
#  {'name': 'm406',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Equity_prices_L1']},
#  {'name': 'm407',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Equity_prices_L2']},
#  {'name': 'm408',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Equity_prices_L3']},
#  {'name': 'm409',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Equity_prices_L4']},
#  {'name': 'm415',
#   'x': ['US_Effective_exchange_rate_L4', 'US_House_prices_residential_L0']},
#  {'name': 'm416',
#   'x': ['US_Effective_exchange_rate_L4', 'US_House_prices_residential_L1']},
#  {'name': 'm417',
#   'x': ['US_Effective_exchange_rate_L4', 'US_House_prices_residential_L2']},
#  {'name': 'm418',
#   'x': ['US_Effective_exchange_rate_L4', 'US_House_prices_residential_L3']},
#  {'name': 'm421',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Inflation_rate_L1']},
#  {'name': 'm422',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Inflation_rate_L2']},
#  {'name': 'm423',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Inflation_rate_L3']},
#  {'name': 'm424',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Inflation_rate_L4']},
#  {'name': 'm426',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm427',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm428',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm429',
#   'x': ['US_Effective_exchange_rate_L4', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm430', 'x': ['US_Effective_exchange_rate_L4', 'US_Oil_price_L0']},
#  {'name': 'm431', 'x': ['US_Effective_exchange_rate_L4', 'US_Oil_price_L1']},
#  {'name': 'm432', 'x': ['US_Effective_exchange_rate_L4', 'US_Oil_price_L2']},
#  {'name': 'm433', 'x': ['US_Effective_exchange_rate_L4', 'US_Oil_price_L3']},
#  {'name': 'm434', 'x': ['US_Effective_exchange_rate_L4', 'US_Oil_price_L4']},
#  {'name': 'm440', 'x': ['US_Equity_prices_L0', 'US_Equity_prices_L1']},
#  {'name': 'm441', 'x': ['US_Equity_prices_L0', 'US_Equity_prices_L2']},
#  {'name': 'm442', 'x': ['US_Equity_prices_L0', 'US_Equity_prices_L3']},
#  {'name': 'm443', 'x': ['US_Equity_prices_L0', 'US_Equity_prices_L4']},
#  {'name': 'm449',
#   'x': ['US_Equity_prices_L0', 'US_House_prices_residential_L0']},
#  {'name': 'm450',
#   'x': ['US_Equity_prices_L0', 'US_House_prices_residential_L1']},
#  {'name': 'm451',
#   'x': ['US_Equity_prices_L0', 'US_House_prices_residential_L2']},
#  {'name': 'm452',
#   'x': ['US_Equity_prices_L0', 'US_House_prices_residential_L3']},
#  {'name': 'm455', 'x': ['US_Equity_prices_L0', 'US_Inflation_rate_L1']},
#  {'name': 'm456', 'x': ['US_Equity_prices_L0', 'US_Inflation_rate_L2']},
#  {'name': 'm457', 'x': ['US_Equity_prices_L0', 'US_Inflation_rate_L3']},
#  {'name': 'm458', 'x': ['US_Equity_prices_L0', 'US_Inflation_rate_L4']},
#  {'name': 'm459',
#   'x': ['US_Equity_prices_L0', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm460',
#   'x': ['US_Equity_prices_L0', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm461',
#   'x': ['US_Equity_prices_L0', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm462',
#   'x': ['US_Equity_prices_L0', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm463',
#   'x': ['US_Equity_prices_L0', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm464', 'x': ['US_Equity_prices_L0', 'US_Oil_price_L0']},
#  {'name': 'm465', 'x': ['US_Equity_prices_L0', 'US_Oil_price_L1']},
#  {'name': 'm466', 'x': ['US_Equity_prices_L0', 'US_Oil_price_L2']},
#  {'name': 'm467', 'x': ['US_Equity_prices_L0', 'US_Oil_price_L3']},
#  {'name': 'm468', 'x': ['US_Equity_prices_L0', 'US_Oil_price_L4']},
#  {'name': 'm474', 'x': ['US_Equity_prices_L1', 'US_Equity_prices_L2']},
#  {'name': 'm475', 'x': ['US_Equity_prices_L1', 'US_Equity_prices_L3']},
#  {'name': 'm476', 'x': ['US_Equity_prices_L1', 'US_Equity_prices_L4']},
#  {'name': 'm482',
#   'x': ['US_Equity_prices_L1', 'US_House_prices_residential_L0']},
#  {'name': 'm483',
#   'x': ['US_Equity_prices_L1', 'US_House_prices_residential_L1']},
#  {'name': 'm484',
#   'x': ['US_Equity_prices_L1', 'US_House_prices_residential_L2']},
#  {'name': 'm487', 'x': ['US_Equity_prices_L1', 'US_Inflation_rate_L0']},
#  {'name': 'm488', 'x': ['US_Equity_prices_L1', 'US_Inflation_rate_L1']},
#  {'name': 'm489', 'x': ['US_Equity_prices_L1', 'US_Inflation_rate_L2']},
#  {'name': 'm490', 'x': ['US_Equity_prices_L1', 'US_Inflation_rate_L3']},
#  {'name': 'm491', 'x': ['US_Equity_prices_L1', 'US_Inflation_rate_L4']},
#  {'name': 'm492',
#   'x': ['US_Equity_prices_L1', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm493',
#   'x': ['US_Equity_prices_L1', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm494',
#   'x': ['US_Equity_prices_L1', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm495',
#   'x': ['US_Equity_prices_L1', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm496',
#   'x': ['US_Equity_prices_L1', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm497', 'x': ['US_Equity_prices_L1', 'US_Oil_price_L0']},
#  {'name': 'm498', 'x': ['US_Equity_prices_L1', 'US_Oil_price_L1']},
#  {'name': 'm499', 'x': ['US_Equity_prices_L1', 'US_Oil_price_L2']},
#  {'name': 'm500', 'x': ['US_Equity_prices_L1', 'US_Oil_price_L3']},
#  {'name': 'm501', 'x': ['US_Equity_prices_L1', 'US_Oil_price_L4']},
#  {'name': 'm507', 'x': ['US_Equity_prices_L2', 'US_Equity_prices_L3']},
#  {'name': 'm508', 'x': ['US_Equity_prices_L2', 'US_Equity_prices_L4']},
#  {'name': 'm509', 'x': ['US_Equity_prices_L2', 'US_GDP_Growth_Rate_L0']},
#  {'name': 'm514',
#   'x': ['US_Equity_prices_L2', 'US_House_prices_residential_L0']},
#  {'name': 'm515',
#   'x': ['US_Equity_prices_L2', 'US_House_prices_residential_L1']},
#  {'name': 'm516',
#   'x': ['US_Equity_prices_L2', 'US_House_prices_residential_L2']},
#  {'name': 'm520', 'x': ['US_Equity_prices_L2', 'US_Inflation_rate_L1']},
#  {'name': 'm521', 'x': ['US_Equity_prices_L2', 'US_Inflation_rate_L2']},
#  {'name': 'm522', 'x': ['US_Equity_prices_L2', 'US_Inflation_rate_L3']},
#  {'name': 'm523', 'x': ['US_Equity_prices_L2', 'US_Inflation_rate_L4']},
#  {'name': 'm525',
#   'x': ['US_Equity_prices_L2', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm526',
#   'x': ['US_Equity_prices_L2', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm527',
#   'x': ['US_Equity_prices_L2', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm528',
#   'x': ['US_Equity_prices_L2', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm529', 'x': ['US_Equity_prices_L2', 'US_Oil_price_L0']},
#  {'name': 'm530', 'x': ['US_Equity_prices_L2', 'US_Oil_price_L1']},
#  {'name': 'm531', 'x': ['US_Equity_prices_L2', 'US_Oil_price_L2']},
#  {'name': 'm532', 'x': ['US_Equity_prices_L2', 'US_Oil_price_L3']},
#  {'name': 'm533', 'x': ['US_Equity_prices_L2', 'US_Oil_price_L4']},
#  {'name': 'm539', 'x': ['US_Equity_prices_L3', 'US_Equity_prices_L4']},
#  {'name': 'm545',
#   'x': ['US_Equity_prices_L3', 'US_House_prices_residential_L0']},
#  {'name': 'm546',
#   'x': ['US_Equity_prices_L3', 'US_House_prices_residential_L1']},
#  {'name': 'm547',
#   'x': ['US_Equity_prices_L3', 'US_House_prices_residential_L2']},
#  {'name': 'm548',
#   'x': ['US_Equity_prices_L3', 'US_House_prices_residential_L3']},
#  {'name': 'm551', 'x': ['US_Equity_prices_L3', 'US_Inflation_rate_L1']},
#  {'name': 'm552', 'x': ['US_Equity_prices_L3', 'US_Inflation_rate_L2']},
#  {'name': 'm553', 'x': ['US_Equity_prices_L3', 'US_Inflation_rate_L3']},
#  {'name': 'm554', 'x': ['US_Equity_prices_L3', 'US_Inflation_rate_L4']},
#  {'name': 'm556',
#   'x': ['US_Equity_prices_L3', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm557',
#   'x': ['US_Equity_prices_L3', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm558',
#   'x': ['US_Equity_prices_L3', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm559',
#   'x': ['US_Equity_prices_L3', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm560', 'x': ['US_Equity_prices_L3', 'US_Oil_price_L0']},
#  {'name': 'm561', 'x': ['US_Equity_prices_L3', 'US_Oil_price_L1']},
#  {'name': 'm562', 'x': ['US_Equity_prices_L3', 'US_Oil_price_L2']},
#  {'name': 'm563', 'x': ['US_Equity_prices_L3', 'US_Oil_price_L3']},
#  {'name': 'm564', 'x': ['US_Equity_prices_L3', 'US_Oil_price_L4']},
#  {'name': 'm575',
#   'x': ['US_Equity_prices_L4', 'US_House_prices_residential_L0']},
#  {'name': 'm576',
#   'x': ['US_Equity_prices_L4', 'US_House_prices_residential_L1']},
#  {'name': 'm577',
#   'x': ['US_Equity_prices_L4', 'US_House_prices_residential_L2']},
#  {'name': 'm578',
#   'x': ['US_Equity_prices_L4', 'US_House_prices_residential_L3']},
#  {'name': 'm581', 'x': ['US_Equity_prices_L4', 'US_Inflation_rate_L1']},
#  {'name': 'm582', 'x': ['US_Equity_prices_L4', 'US_Inflation_rate_L2']},
#  {'name': 'm583', 'x': ['US_Equity_prices_L4', 'US_Inflation_rate_L3']},
#  {'name': 'm584', 'x': ['US_Equity_prices_L4', 'US_Inflation_rate_L4']},
#  {'name': 'm586',
#   'x': ['US_Equity_prices_L4', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm587',
#   'x': ['US_Equity_prices_L4', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm588',
#   'x': ['US_Equity_prices_L4', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm589',
#   'x': ['US_Equity_prices_L4', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm590', 'x': ['US_Equity_prices_L4', 'US_Oil_price_L0']},
#  {'name': 'm591', 'x': ['US_Equity_prices_L4', 'US_Oil_price_L1']},
#  {'name': 'm592', 'x': ['US_Equity_prices_L4', 'US_Oil_price_L2']},
#  {'name': 'm593', 'x': ['US_Equity_prices_L4', 'US_Oil_price_L3']},
#  {'name': 'm594', 'x': ['US_Equity_prices_L4', 'US_Oil_price_L4']},
#  {'name': 'm609', 'x': ['US_GDP_Growth_Rate_L0', 'US_Inflation_rate_L0']},
#  {'name': 'm611', 'x': ['US_GDP_Growth_Rate_L0', 'US_Inflation_rate_L2']},
#  {'name': 'm612', 'x': ['US_GDP_Growth_Rate_L0', 'US_Inflation_rate_L3']},
#  {'name': 'm614',
#   'x': ['US_GDP_Growth_Rate_L0', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm617',
#   'x': ['US_GDP_Growth_Rate_L0', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm618',
#   'x': ['US_GDP_Growth_Rate_L0', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm622', 'x': ['US_GDP_Growth_Rate_L0', 'US_Oil_price_L3']},
#  {'name': 'm729', 'x': ['US_GDP_Growth_Rate_L4', 'US_Oil_price_L4']},
#  {'name': 'm735',
#   'x': ['US_House_prices_residential_L0', 'US_House_prices_residential_L1']},
#  {'name': 'm739',
#   'x': ['US_House_prices_residential_L0', 'US_Inflation_rate_L0']},
#  {'name': 'm740',
#   'x': ['US_House_prices_residential_L0', 'US_Inflation_rate_L1']},
#  {'name': 'm741',
#   'x': ['US_House_prices_residential_L0', 'US_Inflation_rate_L2']},
#  {'name': 'm742',
#   'x': ['US_House_prices_residential_L0', 'US_Inflation_rate_L3']},
#  {'name': 'm743',
#   'x': ['US_House_prices_residential_L0', 'US_Inflation_rate_L4']},
#  {'name': 'm744',
#   'x': ['US_House_prices_residential_L0', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm745',
#   'x': ['US_House_prices_residential_L0', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm746',
#   'x': ['US_House_prices_residential_L0', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm747',
#   'x': ['US_House_prices_residential_L0', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm748',
#   'x': ['US_House_prices_residential_L0', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm749', 'x': ['US_House_prices_residential_L0', 'US_Oil_price_L0']},
#  {'name': 'm750', 'x': ['US_House_prices_residential_L0', 'US_Oil_price_L1']},
#  {'name': 'm751', 'x': ['US_House_prices_residential_L0', 'US_Oil_price_L2']},
#  {'name': 'm752', 'x': ['US_House_prices_residential_L0', 'US_Oil_price_L3']},
#  {'name': 'm753', 'x': ['US_House_prices_residential_L0', 'US_Oil_price_L4']},
#  {'name': 'm758',
#   'x': ['US_House_prices_residential_L0', 'US_Unemployment_rate_L4']},
#  {'name': 'm762',
#   'x': ['US_House_prices_residential_L1', 'US_Inflation_rate_L0']},
#  {'name': 'm763',
#   'x': ['US_House_prices_residential_L1', 'US_Inflation_rate_L1']},
#  {'name': 'm764',
#   'x': ['US_House_prices_residential_L1', 'US_Inflation_rate_L2']},
#  {'name': 'm765',
#   'x': ['US_House_prices_residential_L1', 'US_Inflation_rate_L3']},
#  {'name': 'm766',
#   'x': ['US_House_prices_residential_L1', 'US_Inflation_rate_L4']},
#  {'name': 'm767',
#   'x': ['US_House_prices_residential_L1', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm768',
#   'x': ['US_House_prices_residential_L1', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm769',
#   'x': ['US_House_prices_residential_L1', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm770',
#   'x': ['US_House_prices_residential_L1', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm771',
#   'x': ['US_House_prices_residential_L1', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm772', 'x': ['US_House_prices_residential_L1', 'US_Oil_price_L0']},
#  {'name': 'm773', 'x': ['US_House_prices_residential_L1', 'US_Oil_price_L1']},
#  {'name': 'm774', 'x': ['US_House_prices_residential_L1', 'US_Oil_price_L2']},
#  {'name': 'm775', 'x': ['US_House_prices_residential_L1', 'US_Oil_price_L3']},
#  {'name': 'm776', 'x': ['US_House_prices_residential_L1', 'US_Oil_price_L4']},
#  {'name': 'm785',
#   'x': ['US_House_prices_residential_L2', 'US_Inflation_rate_L1']},
#  {'name': 'm786',
#   'x': ['US_House_prices_residential_L2', 'US_Inflation_rate_L2']},
#  {'name': 'm787',
#   'x': ['US_House_prices_residential_L2', 'US_Inflation_rate_L3']},
#  {'name': 'm788',
#   'x': ['US_House_prices_residential_L2', 'US_Inflation_rate_L4']},
#  {'name': 'm790',
#   'x': ['US_House_prices_residential_L2', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm791',
#   'x': ['US_House_prices_residential_L2', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm792',
#   'x': ['US_House_prices_residential_L2', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm793',
#   'x': ['US_House_prices_residential_L2', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm794', 'x': ['US_House_prices_residential_L2', 'US_Oil_price_L0']},
#  {'name': 'm795', 'x': ['US_House_prices_residential_L2', 'US_Oil_price_L1']},
#  {'name': 'm796', 'x': ['US_House_prices_residential_L2', 'US_Oil_price_L2']},
#  {'name': 'm797', 'x': ['US_House_prices_residential_L2', 'US_Oil_price_L3']},
#  {'name': 'm798', 'x': ['US_House_prices_residential_L2', 'US_Oil_price_L4']},
#  {'name': 'm806',
#   'x': ['US_House_prices_residential_L3', 'US_Inflation_rate_L1']},
#  {'name': 'm807',
#   'x': ['US_House_prices_residential_L3', 'US_Inflation_rate_L2']},
#  {'name': 'm808',
#   'x': ['US_House_prices_residential_L3', 'US_Inflation_rate_L3']},
#  {'name': 'm809',
#   'x': ['US_House_prices_residential_L3', 'US_Inflation_rate_L4']},
#  {'name': 'm811',
#   'x': ['US_House_prices_residential_L3', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm812',
#   'x': ['US_House_prices_residential_L3', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm813',
#   'x': ['US_House_prices_residential_L3', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm814',
#   'x': ['US_House_prices_residential_L3', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm816', 'x': ['US_House_prices_residential_L3', 'US_Oil_price_L1']},
#  {'name': 'm817', 'x': ['US_House_prices_residential_L3', 'US_Oil_price_L2']},
#  {'name': 'm819', 'x': ['US_House_prices_residential_L3', 'US_Oil_price_L4']},
#  {'name': 'm832',
#   'x': ['US_House_prices_residential_L4', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm833',
#   'x': ['US_House_prices_residential_L4', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm848', 'x': ['US_Inflation_rate_L0', 'US_Inflation_rate_L4']},
#  {'name': 'm853',
#   'x': ['US_Inflation_rate_L0', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm854', 'x': ['US_Inflation_rate_L0', 'US_Oil_price_L0']},
#  {'name': 'm858', 'x': ['US_Inflation_rate_L0', 'US_Oil_price_L4']},
#  {'name': 'm864', 'x': ['US_Inflation_rate_L1', 'US_Inflation_rate_L2']},
#  {'name': 'm865', 'x': ['US_Inflation_rate_L1', 'US_Inflation_rate_L3']},
#  {'name': 'm866', 'x': ['US_Inflation_rate_L1', 'US_Inflation_rate_L4']},
#  {'name': 'm867',
#   'x': ['US_Inflation_rate_L1', 'US_Long_term_interest_rate_L0']},
#  {'name': 'm868',
#   'x': ['US_Inflation_rate_L1', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm869',
#   'x': ['US_Inflation_rate_L1', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm870',
#   'x': ['US_Inflation_rate_L1', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm871',
#   'x': ['US_Inflation_rate_L1', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm872', 'x': ['US_Inflation_rate_L1', 'US_Oil_price_L0']},
#  {'name': 'm873', 'x': ['US_Inflation_rate_L1', 'US_Oil_price_L1']},
#  {'name': 'm874', 'x': ['US_Inflation_rate_L1', 'US_Oil_price_L2']},
#  {'name': 'm875', 'x': ['US_Inflation_rate_L1', 'US_Oil_price_L3']},
#  {'name': 'm876', 'x': ['US_Inflation_rate_L1', 'US_Oil_price_L4']},
#  {'name': 'm882', 'x': ['US_Inflation_rate_L2', 'US_Inflation_rate_L3']},
#  {'name': 'm883', 'x': ['US_Inflation_rate_L2', 'US_Inflation_rate_L4']},
#  {'name': 'm885',
#   'x': ['US_Inflation_rate_L2', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm887',
#   'x': ['US_Inflation_rate_L2', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm888',
#   'x': ['US_Inflation_rate_L2', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm889', 'x': ['US_Inflation_rate_L2', 'US_Oil_price_L0']},
#  {'name': 'm890', 'x': ['US_Inflation_rate_L2', 'US_Oil_price_L1']},
#  {'name': 'm891', 'x': ['US_Inflation_rate_L2', 'US_Oil_price_L2']},
#  {'name': 'm892', 'x': ['US_Inflation_rate_L2', 'US_Oil_price_L3']},
#  {'name': 'm893', 'x': ['US_Inflation_rate_L2', 'US_Oil_price_L4']},
#  {'name': 'm899', 'x': ['US_Inflation_rate_L3', 'US_Inflation_rate_L4']},
#  {'name': 'm901',
#   'x': ['US_Inflation_rate_L3', 'US_Long_term_interest_rate_L1']},
#  {'name': 'm902',
#   'x': ['US_Inflation_rate_L3', 'US_Long_term_interest_rate_L2']},
#  {'name': 'm903',
#   'x': ['US_Inflation_rate_L3', 'US_Long_term_interest_rate_L3']},
#  {'name': 'm904',
#   'x': ['US_Inflation_rate_L3', 'US_Long_term_interest_rate_L4']},
#  {'name': 'm905', 'x': ['US_Inflation_rate_L3', 'US_Oil_price_L0']},
#  {'name': 'm906', 'x': ['US_Inflation_rate_L3', 'US_Oil_price_L1']},
#  {'name': 'm907', 'x': ['US_Inflation_rate_L3', 'US_Oil_price_L2']},
#  {'name': 'm908', 'x': ['US_Inflation_rate_L3', 'US_Oil_price_L3']},
#  {'name': 'm909', 'x': ['US_Inflation_rate_L3', 'US_Oil_price_L4']},
#  {'name': 'm916',
# ...
#  {'name': 'm1528',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1529',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1530',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1533',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1534',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1535',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1536',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Oil_price_L0']},
#  {'name': 'm1537',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Oil_price_L1']},
#  {'name': 'm1538',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Oil_price_L2']},
#  {'name': 'm1539',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Oil_price_L3']},
#  {'name': 'm1540',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Oil_price_L4']},
#  {'name': 'm1541',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_Equity_prices_L4',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm1550',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_House_prices_residential_L0']},
#  {'name': 'm1551',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_House_prices_residential_L1']},
#  {'name': 'm1552',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_House_prices_residential_L2']},
#  {'name': 'm1553',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_House_prices_residential_L3']},
#  {'name': 'm1554',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_House_prices_residential_L4']},
#  {'name': 'm1555',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Inflation_rate_L0']},
#  {'name': 'm1556',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1557',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1558',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1559',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1562',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1563',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1564',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1565',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Oil_price_L0']},
#  {'name': 'm1566',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Oil_price_L1']},
#  {'name': 'm1567',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Oil_price_L2']},
#  {'name': 'm1568',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Oil_price_L3']},
#  {'name': 'm1569',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Oil_price_L4']},
#  {'name': 'm1574',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L0',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm1670',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L4',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1675',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_GDP_Growth_Rate_L4',
#    'US_Oil_price_L4']},
#  {'name': 'm1682',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_House_prices_residential_L2']},
#  {'name': 'm1685',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Inflation_rate_L0']},
#  {'name': 'm1686',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1687',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1688',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1689',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1692',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1693',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1694',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1695',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Oil_price_L0']},
#  {'name': 'm1696',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Oil_price_L1']},
#  {'name': 'm1697',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Oil_price_L2']},
#  {'name': 'm1698',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Oil_price_L3']},
#  {'name': 'm1699',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Oil_price_L4']},
#  {'name': 'm1700',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm1704',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L0',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm1708',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Inflation_rate_L0']},
#  {'name': 'm1709',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1710',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1711',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1712',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1714',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Long_term_interest_rate_L1']},
#  {'name': 'm1715',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1716',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1717',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1718',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Oil_price_L0']},
#  {'name': 'm1719',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Oil_price_L1']},
#  {'name': 'm1720',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Oil_price_L2']},
#  {'name': 'm1721',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Oil_price_L3']},
#  {'name': 'm1722',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Oil_price_L4']},
#  {'name': 'm1723',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm1727',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L1',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm1731',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1732',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1733',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1734',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1737',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1738',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1739',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1740',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Oil_price_L0']},
#  {'name': 'm1741',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Oil_price_L1']},
#  {'name': 'm1742',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Oil_price_L2']},
#  {'name': 'm1743',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Oil_price_L3']},
#  {'name': 'm1744',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Oil_price_L4']},
#  {'name': 'm1745',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm1749',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L2',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm1752',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1753',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1754',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1755',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1758',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1759',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1760',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1761',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Oil_price_L0']},
#  {'name': 'm1762',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Oil_price_L1']},
#  {'name': 'm1763',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Oil_price_L2']},
#  {'name': 'm1764',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Oil_price_L3']},
#  {'name': 'm1765',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Oil_price_L4']},
#  {'name': 'm1766',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Unemployment_rate_L0']},
#  {'name': 'm1770',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L3',
#    'US_Unemployment_rate_L4']},
#  {'name': 'm1772',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Inflation_rate_L1']},
#  {'name': 'm1773',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Inflation_rate_L2']},
#  {'name': 'm1774',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Inflation_rate_L3']},
#  {'name': 'm1775',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Inflation_rate_L4']},
#  {'name': 'm1778',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Long_term_interest_rate_L2']},
#  {'name': 'm1779',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Long_term_interest_rate_L3']},
#  {'name': 'm1780',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Long_term_interest_rate_L4']},
#  {'name': 'm1781',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Oil_price_L0']},
#  {'name': 'm1782',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Oil_price_L1']},
#  {'name': 'm1783',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Oil_price_L2']},
#  {'name': 'm1784',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Oil_price_L3']},
#  {'name': 'm1785',
#   'x': ['US_Central_bank_Intervention_rate_policy_interest_rate_L0',
#    'US_House_prices_residential_L4',
#    'US_Oil_price_L4']},
#  ...]

# %%
df_used
# Out:
#           Zt  US_Central_bank_Intervention_rate_policy_interest_rate_L0  \
# 0  -0.113729                                                NaN
# 1   0.865167                                           0.000000
# 2   1.182152                                           0.000000
# 3   1.001547                                           0.000000
# 4   0.093760                                           0.000000
# 5  -0.582303                                           0.000000
# 6  -0.634776                                           0.000000
# 7   0.219300                                           0.000000
# 8   0.027697                                           0.000000
# 9   0.401578                                           0.000000
# 10 -0.069836                                           0.000000
# 11 -0.096481                                           0.000000
# 12  0.924171                                           0.000000
# 13  0.727494                                           0.000000
# 14  0.802684                                           0.000000
# 15  0.424726                                           0.000000
# 16 -0.005408                                           0.000000
# 17 -0.198245                                           0.000000
# 18 -0.172365                                           0.000000
# 19 -0.519077                                           0.000000
# 20 -0.445036                                           0.000000
# 21 -0.009234                                           0.000000
# 22  0.034046                                           0.000000
# 23  0.239146                                           0.083333
# 24 -0.222951                                           0.166667
# 25 -0.752658                                           0.000000
# 26 -0.620566                                           0.000000
# 27 -0.348269                                           0.083333
# 28 -0.162695                                           0.250000
# 29  0.110625                                           0.250000
# 30  0.341075                                           0.166667
# 31  0.280355                                           0.083333
# 32  0.359940                                           0.250000
# 33 -0.471350                                           0.250000
# 34 -0.962522                                           0.250000
# 35 -1.927952                                           0.250000
# 38                                           0.250000
# 39                                           0.250000
# 40                                           0.166667
# 41                                           0.000000
# 42                                          -0.250000
# 43                                          -0.500000
# 44                                          -0.500000
# 45                                          -1.000000
# 46                                           0.000000
# 47                                           0.000000
# 48                                           0.000000
# 49                                           0.000000
# 50                                           0.000000
# 51                                           0.000000
#
#     US_Effective_exchange_rate_L0  US_Effective_exchange_rate_L1  \
# 0                             NaN                            NaN
# 1                        0.015999                            NaN
# 2                       -0.013838                       0.015999
# 3                       -0.042496                      -0.013838
# 4                       -0.012943                      -0.042496
# 5                       -0.017790                      -0.012943
# 6                        0.006315                      -0.017790
# 7                        0.029280                       0.006315
# 8                       -0.007445                       0.029280
# 9                        0.021248                      -0.007445
# 10                      -0.001086                       0.021248
# 11                      -0.021148                      -0.001086
# 12                       0.004306                      -0.021148
# 13                       0.011758                       0.004306
# 14                       0.009660                       0.011758
# 15                      -0.015217                       0.009660
# 16                       0.013974                      -0.015217
# 17                       0.001283                       0.013974
# 18                       0.006906                       0.001283
# 19                       0.031829                       0.006906
# 20                       0.048623                       0.031829
# 21                       0.012439                       0.048623
# 22                       0.031263                       0.012439
# 23                       0.008328                       0.031263
# 24                       0.016724                       0.008328
# 25                      -0.017526                       0.016724
# 26                       0.009337                      -0.017526
# 27                       0.029815                       0.009337
# 28                       0.007583                       0.029815
# 29                      -0.023367                       0.007583
# 30                      -0.035437                      -0.023367
# 31                       0.003945                      -0.035437
# 32                      -0.028058                       0.003945
# 33                       0.028761                      -0.028058
# 34                       0.026932                       0.028761
# 35                       0.011358                       0.026932
# 36                      -0.012076                       0.011358
# 37                       0.012583                      -0.012076
# 38                       0.008648                       0.012583
# 39                      -0.006858                       0.008648
# 40                       0.008064                      -0.006858
# 41                       0.036988                       0.008064
# 42                      -0.031648                       0.036988
# 43                      -0.033129                      -0.031648
# 44                      -0.014801                      -0.033129
# 45                       0.013389                      -0.014801
# 46                       0.019753                       0.013389
# 47                       0.016118                       0.019753
# 48                       0.010976                       0.016118
# 49                       0.040623                       0.010976
# 50                       0.038369                       0.040623
# 51                       0.004426                       0.038369
#
#     US_Effective_exchange_rate_L2  US_Effective_exchange_rate_L3  ...  \
# 0                             NaN                            NaN  ...
# 1                             NaN                            NaN  ...
# 2                             NaN                            NaN  ...
# 3                        0.015999                            NaN  ...
# 4                       -0.013838                       0.015999  ...
# 5                       -0.042496                      -0.013838  ...
# 6                       -0.012943                      -0.042496  ...
# 7                       -0.017790                      -0.012943  ...
# 8                        0.006315                      -0.017790  ...
# 9                        0.029280                       0.006315  ...
# 10                      -0.007445                       0.029280  ...
# 11                       0.021248                      -0.007445  ...
# 12                      -0.001086                       0.021248  ...
# 13                      -0.021148                      -0.001086  ...
# 14                       0.004306                      -0.021148  ...
# 15                       0.011758                       0.004306  ...
# 16                       0.009660                       0.011758  ...
# 17                      -0.015217                       0.009660  ...
# 18                       0.013974                      -0.015217  ...
# 19                       0.001283                       0.013974  ...
# 20                       0.006906                       0.001283  ...
# 21                       0.031829                       0.006906  ...
# 22                       0.048623                       0.031829  ...
# 51         0.085828                 0.033334                -0.100000
#
#     US_Unemployment_rate_L2  US_Unemployment_rate_L3  US_Unemployment_rate_L4
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                 -0.200000                      NaN                      NaN
# 4                 -0.166667                -0.200000                      NaN
# 5                  0.033334                -0.166667                -0.200000
# 6                 -0.466666                 0.033334                -0.166667
# 7                  0.033333                -0.466666                 0.033334
# 8                 -0.066667                 0.033333                -0.466666
# 9                 -0.366667                -0.066667                 0.033333
# 10                -0.366667                -0.366667                -0.066667
# 11                -0.066666                -0.366667                -0.366667
# 12                -0.166666                -0.066666                -0.366667
# 13                -0.233334                -0.166666                -0.066666
# 14                -0.066667                -0.233334                -0.166666
# 15                -0.200000                -0.066667                -0.233334
# 16                -0.300000                -0.200000                -0.066667
# 17                -0.300000                -0.300000                -0.200000
# 18                -0.266666                -0.300000                -0.300000
# 19                -0.466667                -0.266666                -0.300000
# 20                -0.133333                -0.466667                -0.266666
# 21                -0.366667                -0.133333                -0.466667
# 22                -0.166667                -0.366667                -0.133333
# 23                -0.100000                -0.166667                -0.366667
# 24                -0.333333                -0.100000                -0.166667
# 25                -0.066667                -0.333333                -0.100000
# 26                -0.133333                -0.066667                -0.333333
# 27                 0.033333                -0.133333                -0.066667
# 28                -0.033333                 0.033333                -0.133333
# 29                -0.133333                -0.033333                 0.033333
# 30                -0.200000                -0.133333                -0.033333
# 31                -0.200000                -0.200000                -0.133333
# 32                -0.033334                -0.200000                -0.200000
# 33                -0.166666                -0.033334                -0.200000
# 34                -0.133334                -0.166666                -0.033334
# 35                -0.100000                -0.133334                -0.166666
# 36                -0.166666                -0.100000                -0.133334
# 37                 0.066666                -0.166666                -0.100000
# 38                 0.033334                 0.066666                -0.166666
# 39                -0.233334                 0.033334                 0.066666
# 40                -0.033333                -0.233334                 0.033334
# 41                 0.000000                -0.033333                -0.233334
# 42                 0.233333                 0.000000                -0.033333
# 43                 9.166667                 0.233333                 0.000000
# 44                -4.200000                 9.166667                 0.233333
# 45                -2.066667                -4.200000                 9.166667
# 46                -0.500000                -2.066667                -4.200000
# 47                -0.300000                -0.500000                -2.066667
# 48                -0.866666                -0.300000                -0.500000
# 49                -0.900000                -0.866666                -0.300000
# 50                -0.333334                -0.900000                -0.866666
# 51                -0.200000                -0.333334                -0.900000
#
# [52 rows x 46 columns]

# %%
expected_sign_lagged = expand_expected_sign(EXPECTED_SIGN, lags=(0,1,2,3,4))

kept, filt_summary = build_candidate_pool_and_filter(
    df=df_used,                   # IMPORTANT: df_used contient les colonnes laggées
    y_col=y_col,
    candidate_models=admissible,  # admissible = list of {"name","x"}
    expected_sign=expected_sign_lagged,
    hac_lags=4,
    lb_lags=12,
    alpha=0.05,
    require_sig=True,
    sig_alpha=0.05,
    min_sig=1,
    enforce_bp=False,
    enforce_lb=True
)

filt_summary.head(20)
print("Nb modèles gardés:", len(kept))
2
# Out:
# Nb modèles gardés: 0

# %%
filt_summary.head(20)
# 1382          0.001091  0.869530       False        True
# 1325          0.000177  0.773379       False        True
# 1322          0.000147  0.772725       False        True
# 1491          0.000543  0.796612       False        True
# 1649          0.002356  0.742752       False       False
# 1373          0.002052  0.748834       False        True
# 1685          0.001759  0.714229       False       False
# 1655          0.002327  0.739046       False       False
# 1682          0.002332  0.734392       False       False
# 1674          0.002506  0.746297       False       False
# 1487          0.002064  0.722119       False       False
# 1329          0.000673  0.732249       False        True
# 1357          0.001318  0.732097       False        True
# 493           0.000354  0.759543       False        True
# 61            0.000566  0.908178       False        True

# %%
res = stacking_and_jma_fixed(
    df=df_used,
    y_col=y_col,
    kept_models=kept,
    hac_lags=4
)
res["yhat_stacked"].dropna().shape


print(res["weights_stacking"].sort_values(ascending=False).head(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 res = stacking_and_jma_fixed(
#       2     df=df_used,
#       3     y_col=y_col,
#       4     kept_models=kept,
#       5     hac_lags=4
#       6 )
#       7 res["yhat_stacked"].dropna().shape
#      10 print(res["weights_stacking"].sort_values(ascending=False).head(10))
#
# Cell In[141], line 72, in stacking_and_jma_fixed(df, y_col, kept_models, hac_lags, add_const, train_slice, pred_slice, weight_fit_slice)
#      69 y = d_w[y_col].values
#      70 Y = d_w[P.columns].values
# ---> 72 w = solve_simplex_weights_slsqp(Y, y)
#      73 if w is None:
#      74     raise RuntimeError("Solver SLSQP a échoué pour les poids.")
#
# Cell In[140], line 17, in solve_simplex_weights_slsqp(Y, y)
#      14     r = y - Y @ w
#      15     return float(r.T @ r)
# ---> 17 res = minimize(obj, w0, method="SLSQP", bounds=bounds, constraints=cons)
#      18 if not res.success:
#      19     return None
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minimize.py:704, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     701 remove_vars = False
#     702 if bounds is not None:
#     703     # convert to new-style bounds so we only have to consider one case
# --> 704     bounds = standardize_bounds(bounds, x0, 'new')
#     705     bounds = _validate_bounds(bounds, x0, meth)
#     707     if meth in {"tnc", "slsqp", "l-bfgs-b"}:
#     708         # These methods can't take the finite-difference derivatives they
#     709         # need when a variable is fixed by the bounds. To avoid this issue,
#    (...)    714
#     715         # determine whether any variables are fixed
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minimize.py:1126, in standardize_bounds(bounds, x0, meth)
#    1123 if meth in {'trust-constr', 'powell', 'nelder-mead', 'cobyla', 'cobyqa',
#    1124             'new'}:
#    1125     if not isinstance(bounds, Bounds):
# -> 1126         lb, ub = old_bound_to_new(bounds)
#    1127         bounds = Bounds(lb, ub)
#    1128 elif meth in ('l-bfgs-b', 'tnc', 'slsqp', 'old'):
#
# File c:\Users\werid\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_constraints.py:437, in old_bound_to_new(bounds)
#     428 def old_bound_to_new(bounds):
#     429     """Convert the old bounds representation to the new one.
#     430
#     431     The new representation is a tuple (lb, ub) and the old one is a list
#    (...)    435     -np.inf/np.inf.
#     436     """
# --> 437     lb, ub = zip(*bounds)
#     439     # Convert occurrences of None to -inf or inf, and replace occurrences of
#     440     # any numpy array x with x.item(). Then wrap the results in numpy arrays.
#     441     lb = np.array([float(_arr_to_scalar(x)) if x is not None else -np.inf
#     442                    for x in lb])
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
res = stacking_and_jma_fixed(
    df=df_used,
    y_col=y_col,
    kept_models=kept,
    hac_lags=4,
    train_slice=slice("2011-04-01", "2024-01-01"),
    pred_slice=slice("2011-04-01", "2024-01-01"),
    weight_fit_slice=slice("2011-04-01", "2024-01-01")  # poids appris sur train
)

# %%
y_meta_col=res["yhat_stacked"]

# %%
best_row = (
    filt_summary
    .query("ok == True")
    .sort_values("bic")
    .iloc[0]
)

best_model_name = best_row["model"]
best_model_name
# Out:
# 'm14897'

# %%
best_model = next(
    m for m in admissible if m["name"] == best_model_name
)

x_best = best_model["x"]
x_best
# Out:
# ['US_Long_term_interest_rate_L1', 'US_Oil_price_L0', 'US_Oil_price_L4']

# %%
y_col
# Out:
# 'Z_PRIMAIRES_and_ÉNERGIE'

# %%
df_used
# Out:
#             Z_PRIMAIRES_and_ÉNERGIE  \
# date
# 2011-04-01                -0.240034
# 2011-07-01                -0.269729
# 2011-10-01                -0.216928
# 2012-01-01                -0.226366
# 2012-04-01                -0.232916
# 2012-07-01                 0.248982
# 2012-10-01                 0.581978
# 2013-01-01                -0.542137
# 2013-04-01                 0.887994
# 2013-07-01                 0.791788
# 2013-10-01                -0.622648
# 2014-01-01                 0.484427
# 2014-04-01                -0.577815
# 2014-07-01                 0.477399
# 2014-10-01                 1.020240
# 2015-01-01                 1.372070
# 2015-04-01                 1.148798
# 2015-07-01                 2.044651
# 2015-10-01                 1.617044
# 2016-01-01                 1.587394
# 2016-04-01                -1.032058
# 2016-07-01                 1.079948
# 2016-10-01                 0.479607
# 2017-01-01                -0.680544
# 2017-04-01                -1.464606
# 2017-07-01                -0.766826
# 2017-10-01                -1.941513
# 2018-01-01                -0.510221
# 2018-04-01                -0.966169
# 2018-07-01                 0.124653
# 2018-10-01                -0.720342
# 2019-01-01                 0.387774
# 2019-04-01                 0.291333
# 2019-07-01                 0.456196
# 2019-10-01                 0.776171
# 2020-01-01                 1.664526
# 2020-04-01                 2.366777
# 2020-07-01                 1.102592
# 2020-10-01                -0.341432
# 2021-01-01                -0.167907
# 2021-04-01                -0.950168
# 2021-07-01                -1.473310
# 2021-10-01                -1.584628
# 2022-01-01                -1.354941
# 2022-04-01                -1.115816
# 2022-07-01                -1.478553
# 2022-10-01                -0.955581
# 2023-01-01                -0.338947
# 2023-04-01                -0.108199
# 2023-07-01                -0.112235
# 2023-10-01                 0.115454
# 2024-01-01                -0.115225
#
#             US_Central_bank_Intervention_rate_policy_interest_rate_L0  \
# date
# 2011-04-01                                                NaN
# 2011-07-01                                           0.000000
# 2011-10-01                                           0.000000
# 2012-01-01                                           0.000000
# 2012-04-01                                           0.000000
# 2012-07-01                                           0.000000
# 2012-10-01                                           0.000000
# 2013-01-01                                           0.000000
# 2013-04-01                                           0.000000
# 2013-07-01                                           0.000000
# 2013-10-01                                           0.000000
# 2014-01-01                                           0.000000
# 2014-04-01                                           0.000000
# 2014-07-01                                           0.000000
# 2014-10-01                -0.266666                -0.300000
# 2015-01-01                -0.466667                -0.266666
# 2015-04-01                -0.133333                -0.466667
# 2015-07-01                -0.366667                -0.133333
# 2015-10-01                -0.166667                -0.366667
# 2016-01-01                -0.100000                -0.166667
# 2016-04-01                -0.333333                -0.100000
# 2016-07-01                -0.066667                -0.333333
# 2016-10-01                -0.133333                -0.066667
# 2017-01-01                 0.033333                -0.133333
# 2017-04-01                -0.033333                 0.033333
# 2017-07-01                -0.133333                -0.033333
# 2017-10-01                -0.200000                -0.133333
# 2018-01-01                -0.200000                -0.200000
# 2018-04-01                -0.033334                -0.200000
# 2018-07-01                -0.166666                -0.033334
# 2018-10-01                -0.133334                -0.166666
# 2019-01-01                -0.100000                -0.133334
# 2019-04-01                -0.166666                -0.100000
# 2019-07-01                 0.066666                -0.166666
# 2019-10-01                 0.033334                 0.066666
# 2020-01-01                -0.233334                 0.033334
# 2020-04-01                -0.033333                -0.233334
# 2020-07-01                 0.000000                -0.033333
# 2020-10-01                 0.233333                 0.000000
# 2021-01-01                 9.166667                 0.233333
# 2021-04-01                -4.200000                 9.166667
# 2021-07-01                -2.066667                -4.200000
# 2021-10-01                -0.500000                -2.066667
# 2022-01-01                -0.300000                -0.500000
# 2022-04-01                -0.866666                -0.300000
# 2022-07-01                -0.900000                -0.866666
# 2022-10-01                -0.333334                -0.900000
# 2023-01-01                -0.200000                -0.333334
# 2023-04-01                -0.100000                -0.200000
# 2023-07-01                 0.033334                -0.100000
# 2023-10-01                -0.033334                 0.033334
# 2024-01-01                 0.000000                -0.033334
#
# [52 rows x 46 columns]

# %%
df2 = df_used[[y_col] + x_best].dropna()

fit = fit_ols_hac(df2, y_col, x_best, hac_lags=4, add_const=True)
ols = fit["ols"]

X = df2[x_best].astype(float)
X = sm.add_constant(X, has_constant="add")
yhat_best = pd.Series(ols.predict(X), index=df2.index, name="yhat_best")

# %%
y_indiv_col=yhat_best

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def plot_predictions_like_example(
    df,
    date_col="date",          # colonne date (datetime ou convertible)
    y_true_col="y_true",      # facteur systémique "véritable"
    y_indiv_col="y_indiv",    # prédiction d'un modèle individuel
    y_meta_col="y_meta",      # prédiction du méta-modèle (stacking/JMA)
    sector_name="Extractions_primaires",
    r2_indiv=None,            # si None -> calculé
    r2_meta=None,             # si None -> calculé
    title_prefix="Prédictions pour le secteur : ",
    figsize=(12, 5),
    savepath=None
):
    """
    Reproduit un graphe proche de ton exemple:
    - noir: y_true
    - bleu: y_indiv
    - rouge pointillé: y_meta
    - ligne horizontale y=0 en gris pointillé
    - légende avec R² adj (ici on met R² simple; si tu veux l'ajusté, passe-le via r2_*)

    df doit contenir au minimum: date_col, y_true_col, y_indiv_col, y_meta_col.
    """
    d = df[[date_col, y_true_col, y_indiv_col, y_meta_col]].copy()
    d[date_col] = pd.to_datetime(d[date_col], errors="coerce")
    d = d.dropna().sort_values(date_col)

    y_true = d[y_true_col].astype(float).values
    y_ind  = d[y_indiv_col].astype(float).values
    y_meta = d[y_meta_col].astype(float).values

    def r2(y, yhat):
        if len(y) < 2:
            return np.nan
        sse = np.sum((y - yhat) ** 2)
        sst = np.sum((y - np.mean(y)) ** 2)
        return np.nan if sst == 0 else 1 - sse / sst

    if r2_indiv is None:
        r2_indiv = r2(y_true, y_ind)
    if r2_meta is None:
        r2_meta = r2(y_true, y_meta)

    plt.figure(figsize=figsize)
    plt.plot(d[date_col], y_true, linewidth=2.5, label="Fac. Sys. véritable")
    plt.plot(d[date_col], y_ind,  linewidth=2.0, label=f"Modèle individuel (R² adj. = {r2_indiv:.2f})")
    plt.plot(d[date_col], y_meta, linewidth=2.0, linestyle="--",
             label=f"Méta-modèle (R² adj. = {r2_meta:.2f})")

    plt.axhline(0, linestyle="--", linewidth=1.0, alpha=0.7)
    plt.grid(True, alpha=0.35)

    plt.title(f"{title_prefix}{sector_name}", fontsize=14)
    plt.ylabel("Facteur systémique", fontsize=12)
    plt.xlabel("Date", fontsize=12)
    plt.legend(loc="upper left", frameon=True)

    plt.tight_layout()
    if savepath:
        plt.savefig(savepath, dpi=200, bbox_inches="tight")
    plt.show()


# ==========================
# EXEMPLE D’UTILISATION
# ==========================
# Tu peux construire df_plot à partir de tes objets:
# - Z observé : df_macro_stationary["Z_..."]
# - prédiction modèle individuel : yhat_best (Series)
# - prédiction méta-modèle : yhat_stacked (Series)

# Exemple type (adapte les noms):
y_col = y_col  # ou "Z_EXTRACTIONS_PRIMAIRES"
y_true = df_macro_stationary[y_col]
yhat_indiv =y_indiv_col           # Series indexée par date
yhat_meta = y_meta_col   # Series indexée par date
#
df_plot = pd.concat(
    [y_true.rename("y_true"),
     yhat_indiv.rename("y_indiv"),
     yhat_meta.rename("y_meta")],
    axis=1
).reset_index().rename(columns={"index": "date"})
#
plot_predictions_like_example(
    df_plot,
    date_col="date",
    y_true_col="y_true",
    y_indiv_col="y_indiv",
    y_meta_col="y_meta",
    sector_name="Extractions_primaires"
 )

# %%
variables = df_merged1.columns.tolist()
stationarity_df = stationarity_tests_summary(df_merged, variables)
stationarity_df
import numpy as np
import pandas as pd

TRANSFORMATIONS = {
    # Interest rates -> difference
    "US_Central_bank_Intervention_rate_policy_interest_rate": "diff",
    "US_Long_term_interest_rate": "diff",

    # Unemployment & inflation -> difference
    "US_Unemployment_rate": "diff",
    "US_Inflation_rate": "diff",

    # Exchange rates -> log ratio
    "US_Effective_exchange_rate": "log_ratio",

    # Prices -> log ratio
    "US_Equity_prices": "log_ratio",
    "US_House_prices_residential": "log_ratio",
    "US_Oil_price": "log_ratio",

    # GDP growth rates -> keep (already stationary in your tests)
    "US_GDP_Growth_Rate": "level",
}

import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss

def _adf_kpss(series, regression="c"):
    s = series.dropna()
    if len(s) < 20:
        return np.nan, np.nan  # pas assez de points
    adf_p = adfuller(s, autolag="AIC")[1]
    kpss_p = kpss(s, regression=regression, nlags="auto")[1]
    return adf_p, kpss_p

def _diagnosis(adf_p, kpss_p, alpha=0.05):
    adf_stat = (adf_p < alpha) if pd.notna(adf_p) else False
    kpss_stat = (kpss_p > alpha) if pd.notna(kpss_p) else False
    if adf_stat and kpss_stat:
        return True, True, "Stationary"
    if (not adf_stat) and (not kpss_stat):
        return False, False, "Non-stationary"
    return adf_stat, kpss_stat, "Ambiguous"

def stationarize_and_test(
    df_wide: pd.DataFrame,
    transformations: dict,
    alpha: float = 0.05,
    kpss_regression: str = "c",
    add_prefix: bool = False,
):
    """
    df_wide: index=date (monthly), columns=variables
    transformations: dict {colname: 'level'|'diff'|'log_ratio'}
    add_prefix: if True, columns are renamed e.g. d_EU_rate, lr_US_fx, ...
    """
    df = df_wide.copy()

    # --- sanity check: missing keys / missing columns
    missing_in_df = [k for k in transformations.keys() if k not in df.columns]
    missing_in_dict = [c for c in df.columns if c not in transformations.keys()]

    if missing_in_df:
        print("⚠️ Keys in TRANSFORMATIONS but not in df columns:", missing_in_df)
    if missing_in_dict:
        print("⚠️ Columns in df but not in TRANSFORMATIONS (kept as level):", missing_in_dict)

    # default = level for unspecified columns
    trans = {c: transformations.get(c, "level") for c in df.columns}

    # --- tests BEFORE
    before_rows = []
    for c in df.columns:
        adf_p, kpss_p = _adf_kpss(df[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        before_rows.append({
            "variable": c,
            "transform": "level",
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    before_df = pd.DataFrame(before_rows)

    # --- apply transformations
    out = pd.DataFrame(index=df.index)

    def apply_one(s, how):
        if how == "level":
            return s
        if how == "diff":
            return s.diff()
        if how == "log_ratio":
            # safe log: only for strictly positive series
            s2 = s.replace(0, np.nan)
            return np.log(s2).diff()
        raise ValueError(f"Unknown transformation: {how}")

    rename_map = {}
    for c in df.columns:
        how = trans[c]
        s_tr = apply_one(df[c], how)
        if add_prefix:
            pref = {"level":"", "diff":"d_", "log_ratio":"lr_"}[how]
            new_name = pref + c
        else:
            new_name = c
        out[new_name] = s_tr
        rename_map[c] = new_name

    # --- tests AFTER
    after_rows = []
    for c_old in df.columns:
        c = rename_map[c_old]
        how = trans[c_old]
        adf_p, kpss_p = _adf_kpss(out[c], regression=kpss_regression)
        adf_ok, kpss_ok, diag = _diagnosis(adf_p, kpss_p, alpha=alpha)
        after_rows.append({
            "variable": c_old,
            "transform": how,
            "adf_pvalue": adf_p,
            "kpss_pvalue": kpss_p,
            "ADF_stationary_5pct": adf_ok,
            "KPSS_stationary_5pct": kpss_ok,
            "diagnosis": diag
        })
    after_df = pd.DataFrame(after_rows)

    return out, before_df, after_df

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# -------------------------------------------------
# Split chronologique uniquement par dates
# -------------------------------------------------

def split_by_dates(df, train_end, test_start=None, test_end=None):
    """
    - train : index <= train_end
    - test  : index >= test_start (ou > train_end si None)
    """
    df = df.sort_index()

    if test_start is None:
        test_start = pd.to_datetime(train_end) + pd.Timedelta(days=1)

    train = df.loc[df.index <= train_end].copy()
    test  = df.loc[df.index >= test_start].copy()

    if test_end is not None:
        test = test.loc[test.index <= test_end]

    return train, test


# -------------------------------------------------
# Métriques OOS
# -------------------------------------------------

def compute_oos_metrics(y_true, y_pred):
    mask = y_true.notna() & y_pred.notna()
    y = y_true[mask]
    yhat = y_pred[mask]

    mse  = float(((y - yhat)**2).mean())
    rmse = float(np.sqrt(mse))
    mae  = float(np.abs(y - yhat).mean())

    # R² OOS
    ss_res = float(((y - yhat)**2).sum())
    ss_tot = float(((y - y.mean())**2).sum())
    r2 = 1 - ss_res/ss_tot if ss_tot > 0 else np.nan

    return {
        "n_obs": int(mask.sum()),
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "R2_OOS": r2
    }


# -------------------------------------------------
# Rolling JMA avec dates + métriques
# -------------------------------------------------

def jma_rolling_dates(
    df,
    y_col,
    kept_models,
    train_end,
    test_start=None,
    test_end=None,
    hac_lags=4,
    add_const=True,
    min_obs=30,
    window=None,              # None = expanding
    relearn_weights=False
):

    df = df.sort_index()

    # -------- SPLIT --------
    train, test = split_by_dates(df, train_end, test_start, test_end)

    # -------- Poids fixes appris sur train --------
    weights_fixed = None
    if not relearn_weights:
        P_loo_train = build_P_loo(train, y_col, kept_models,
                                  hac_lags=hac_lags,
                                  add_const=add_const,
                                  min_obs=min_obs)

        weights_fixed, _ = learn_simplex_weights_from_loo(train, y_col, P_loo_train)

    # -------- Rolling predictions --------
    df_all = pd.concat([train, test]).sort_index()
    yhat_test = pd.Series(index=test.index, dtype=float, name="yhat_jma")

    model_names = [m.get("name", f"m{i}") for i, m in enumerate(kept_models)]
    weights_hist = []

    for t in test.index:

        past = df_all.loc[df_all.index < t].copy()

        if window is not None:
            past = past.iloc[-int(window):]

        if past[y_col].notna().sum() < min_obs:
            yhat_test.loc[t] = np.nan
            continue

        # --- Réapprentissage des poids si demandé ---
        if relearn_weights:
            P_loo_past = build_P_loo(past, y_col, kept_models,
                                     hac_lags=hac_lags,
                                     add_const=add_const,
                                     min_obs=min_obs)
            try:
                w_t, _ = learn_simplex_weights_from_loo(past, y_col, P_loo_past)
            except:
                yhat_test.loc[t] = np.nan
                continue
            weights_hist.append(pd.Series(w_t.values, index=w_t.index, name=t))
            weights_to_use = w_t
        else:
            weights_to_use = weights_fixed

        # --- Fit modèles et prédire à t ---
        preds_t = pd.Series(index=model_names, dtype=float)

        for i, m in enumerate(kept_models):
            name = m.get("name", f"m{i}")
            x_cols = m["x"]

            d_fit = past[[y_col] + x_cols].dropna(subset=[y_col] + x_cols)
            if len(d_fit) < min_obs:
                continue

            fit = fit_ols_hac(d_fit, y_col, x_cols,
                              hac_lags=hac_lags,
                              min_obs=min_obs)
            if fit is None:
                continue

            ols = fit["ols"]

            if t not in df_all.index:
                continue

            x_t = df_all.loc[t, x_cols]
            if x_t.isna().any():
                continue

            X_t = pd.DataFrame([x_t.astype(float).values], columns=x_cols)
            if add_const:
                X_t = sm.add_constant(X_t, has_constant="add")

            preds_t.loc[name] = float(ols.predict(X_t).iloc[0])

        common = preds_t.dropna().index.intersection(weights_to_use.dropna().index)
        if len(common) == 0:
            yhat_test.loc[t] = np.nan
            continue

        w = weights_to_use.loc[common].values
        p = preds_t.loc[common].values

        if w.sum() > 0:
            w = w / w.sum()

        yhat_test.loc[t] = float(p @ w)

    # -------- Métriques OOS --------
    metrics = compute_oos_metrics(test[y_col], yhat_test)

    weights_hist_df = pd.DataFrame(weights_hist) if relearn_weights else None

    return yhat_test, metrics, weights_fixed, weights_hist_df, train, test

# %%
yhat_test, metrics, w_fix, w_hist, train, test = jma_rolling_dates(
    df=df_used_tot,
    y_col="z_t",
    kept_models=kept,
    train_end="2020-10-01",
    test_start="2021-01-01",
    test_end="2023-01-01",
    relearn_weights=False,   # poids fixes
    window=None              # expanding
)

print(metrics)
# Out:
# {'n_obs': 9, 'MSE': 0.4389217493072018, 'RMSE': 0.6625116974870722, 'MAE': 0.5689722776572925, 'R2_OOS': 0.7199163930428782}

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

def rolling_one_model_oos(
    df,
    y_col,
    x_cols,
    test_start,
    test_end=None,
    hac_lags=4,
    add_const=True,
    min_obs=40,
    window=None
):
    """
    Rolling OOS one-step-ahead sur [test_start, test_end].
    Fit sur toutes les dates < t (expanding) ou fenêtre glissante (window).
    """
    df = df.sort_index()
    test_start = pd.to_datetime(test_start)
    if test_end is not None:
        test_end = pd.to_datetime(test_end)

    test_idx = df.index[df.index >= test_start]
    if test_end is not None:
        test_idx = test_idx[test_idx <= test_end]

    yhat = pd.Series(index=test_idx, dtype=float, name="yhat_best_oos")

    for t in test_idx:
        past = df.loc[df.index < t].copy()
        if window is not None:
            past = past.iloc[-int(window):].copy()

        # Fit requires y et X
        d_fit = past[[y_col] + x_cols].dropna(subset=[y_col] + x_cols)
        if len(d_fit) < min_obs:
            continue

        fit = fit_ols_hac(d_fit, y_col, x_cols, hac_lags=hac_lags, min_obs=min_obs)
        if fit is None:
            continue

        # X_t doit exister à t
        if df.loc[t, x_cols].isna().any():
            continue

        X_t = pd.DataFrame([df.loc[t, x_cols].astype(float).values], columns=x_cols)
        if add_const:
            X_t = sm.add_constant(X_t, has_constant="add")

        yhat.loc[t] = float(fit["ols"].predict(X_t).iloc[0])

    return yhat

# %%
# Ton meilleur modèle (comme tu l'as déjà fait)
best_row = (
    summary1.query("ok == True")
            .sort_values("aic", ascending=True)
            .iloc[0]
)
best_model_name = best_row["model"]
best_model = next(m for m in admissible if m["name"] == best_model_name)
x_best = best_model["x"]

# Rolling OOS sur la même fenêtre test que JMA
yhat_best_oos = rolling_one_model_oos(
    df=df_used_tot,
    y_col=y_col,
    x_cols=x_best,
    test_start="2021-01-01",
    test_end="2023-01-01",
    hac_lags=4,
    min_obs=40,
    window=None
)

# %%
metrics_best = compute_oos_metrics(
    df_used_tot.loc[yhat_best_oos.index, y_col],
    yhat_best_oos
)
print(metrics_best)
# Out:
# {'n_obs': 7, 'MSE': 1.1746997820294456, 'RMSE': 1.0838356803637006, 'MAE': 0.9162721552856622, 'R2_OOS': -0.059040704452261616}

# %%
yhat_test

# %%
y_meta_col=yhat_test
best_row = (
    summary1
    .query("ok == True")
    .sort_values("aic", ascending=True)
    .iloc[0]
)

best_model_name = best_row["model"]
best_model_name
best_model = next(
    m for m in admissible if m["name"] == best_model_name
)

x_best = best_model["x"]

df2 = df_used_test[[y_col] + x_best].dropna()

fit = fit_ols_hac(df2, y_col, x_best, hac_lags=4)
ols = fit["ols"]

X = df2[x_best].astype(float)
X = sm.add_constant(X, has_constant="add")
yhat_best = pd.Series(ols.predict(X), index=df2.index, name="yhat_best")

y_indiv_col=yhat_best

x_best
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[109], line 20
#
#      17 df2 = df_used_test[[y_col] + x_best].dropna()
#
#      19 fit = fit_ols_hac(df2, y_col, x_best, hac_lags=4)
#
# ---> 20 ols = fit["ols"]
#
#      22 X = df2[x_best].astype(float)
#
#      23 X = sm.add_constant(X, has_constant="add")
#
#
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import matplotlib.pyplot as plt

train_end = pd.to_datetime("2021-01-01")

df_plot = df_used_tot.sort_index()
mask_test = (df_plot.index >= pd.to_datetime("2021-01-01")) & (df_plot.index <= pd.to_datetime("2023-01-01"))

plt.figure(figsize=(12,6))

# Réel
plt.plot(df_plot.index, df_plot[y_col], linewidth=2, label="Série réelle")

# JMA (test)
plt.plot(yhat_test.index, yhat_test, linewidth=2, label="JMA (OOS, test)")

# Best model (test)
plt.plot(yhat_best_oos.index, yhat_best_oos, linewidth=2, linestyle="--",
         label=f"Meilleur modèle individuel (OOS) : {best_model_name}")

# Séparation train/test
plt.axvline(train_end, linestyle="--", linewidth=2)
plt.axvspan(train_end, df_plot.index.max(), alpha=0.08)

plt.title("Prévisions OOS : JMA vs meilleur modèle individuel")
plt.xlabel("Date")
plt.ylabel(y_col)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_train_test_results(df, y_col, yhat_test,
                            train_end,
                            title="Prédictions",
                            other_series=None):
    """
    df : dataframe complet
    yhat_test : série des prédictions sur test
    train_end : date de fin du train
    other_series : dict facultatif {"Nom": série}
    """

    df = df.sort_index()
    train_end = pd.to_datetime(train_end)

    fig, ax = plt.subplots(figsize=(12,6))

    # ----- Série réelle -----
    ax.plot(df.index, df[y_col],
            label="Série réelle",
            linewidth=2)

    # ----- Prédictions JMA (test uniquement) -----
    ax.plot(yhat_test.index, yhat_test,
            label="JMA (test)",
            linewidth=2)

    # ----- Autres modèles optionnels -----
    if other_series is not None:
        for name, serie in other_series.items():
            ax.plot(serie.index, serie,
                    linestyle="--",
                    label=name)

    # ----- Ligne séparation train/test -----
    ax.axvline(train_end,
               linestyle="--",
               linewidth=2)

    # Zone test légèrement ombrée (optionnel mais très pro)
    ax.axvspan(train_end, df.index.max(),
               alpha=0.08)

    ax.set_title(title)
    ax.set_xlabel("Date")
    ax.set_ylabel(y_col)
    ax.legend()
    ax.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_train_test_results(
    df=df_used_tot,
    y_col="z_t",
    yhat_test=yhat_test,
    train_end="2021-01-01",
    title="Prévisions JMA – Services Pro"
)
